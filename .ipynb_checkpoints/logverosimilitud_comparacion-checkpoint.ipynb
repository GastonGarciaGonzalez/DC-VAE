# %% [markdown]
# Run this notebook to see the outputs of your model.

# %%
import json
import pandas as pd
from utils import preprocessing, set_index
from matplotlib import pyplot as plt
import numpy as np

# %%
settings_path = 'settings\settings_swat_2015_7.txt'
settings = json.load(open(settings_path, 'r'))

input_path = '..\..\Datasets\Scripts\SWaT_Dataset_Normal_v0_preprocessed.csv'
mu_x_path = settings['model_name'] + '_reconstructions.csv'
sigma_x_path = settings['model_name'] + '_sigma.csv'
T = 256

# %%
# Load data and predictions
data = pd.read_csv(input_path)
mu_x = pd.read_csv(mu_x_path)
sigma_x = pd.read_csv(sigma_x_path)

# %%
print(data.shape)
data.head()
# Out:
# (124200, 52)
#              Timestamp    FIT101      LIT101  MV101  P101  P102      AIT201  \
# 0  2015-12-22 16:00:00  2.448836  260.991600    2.0   2.0   1.0  244.328400
# 1  2015-12-22 16:00:04  2.459165  260.186900    2.0   2.0   1.0  244.544650
# 2  2015-12-22 16:00:08  2.609535  261.423350    2.0   2.0   1.0  244.752925
# 3  2015-12-22 16:00:12  2.635637  261.413575    2.0   2.0   1.0  244.953200
# 4  2015-12-22 16:00:16  2.593361  261.109350    2.0   2.0   1.0  245.033300
#
#     AIT202     AIT203    FIT201  ...  FIT504  P501  P502    PIT501  PIT502  \
# 0  8.19008  306.10100  2.468427  ...     0.0   1.0   1.0  10.02948     0.0
# 1  8.19008  306.10100  2.466184  ...     0.0   1.0   1.0  10.02948     0.0
# 2  8.19008  306.10100  2.470894  ...     0.0   1.0   1.0  10.02948     0.0
# 3  8.19008  305.98565  2.474097  ...     0.0   1.0   1.0  10.02948     0.0
# 4  8.19008  305.87030  2.473937  ...     0.0   1.0   1.0  10.02948     0.0
#
#      PIT503    FIT601  P601  P602  P603
# 0  4.277749  0.000256   1.0   1.0   1.0
# 1  4.277749  0.000256   1.0   1.0   1.0
# 2  4.277749  0.000256   1.0   1.0   1.0
# 3  4.277749  0.000256   1.0   1.0   1.0
# 4  4.277749  0.000256   1.0   1.0   1.0
#
# [5 rows x 52 columns]

# %%
print(mu_x.shape)
mu_x.head()
# Out:
# (123945, 52)
#              Timestamp    FIT101    LIT101     MV101      P101      P102  \
# 0  2015-12-22 16:17:00  0.291694 -0.432021  0.593188  0.516327  0.000987
# 1  2015-12-22 16:17:04  0.299960 -0.444407  0.596727  0.523009  0.000988
# 2  2015-12-22 16:17:08  0.296701 -0.418800  0.595231  0.514237  0.000947
# 3  2015-12-22 16:17:12  0.299088 -0.434565  0.594923  0.517583  0.000558
# 4  2015-12-22 16:17:16  0.305840 -0.455189  0.596192  0.516985  0.001087
#
#      AIT201    AIT202    AIT203    FIT201  ...    FIT504      P501      P502  \
# 0  0.947606 -1.330027 -0.080335  0.437990  ...  0.360415  0.082289 -0.000321
# 1  0.899934 -1.263173 -0.093504  0.445479  ...  0.337777  0.081126 -0.000075
# 2  1.034175 -1.268187 -0.120980  0.434580  ...  0.253439  0.081309 -0.000398
# 3  0.952497 -1.275529 -0.107872  0.441569  ...  0.295085  0.081325  0.000009
# 4  0.807841 -1.292760 -0.094567  0.443959  ...  0.311496  0.081534 -0.000181
#
#      PIT501    PIT502    PIT503    FIT601      P601      P602      P603
# 0  0.345182  1.599020  0.461976 -0.093696 -0.000598 -0.063992 -0.000093
# 1  0.282121  1.553339  0.387534 -0.092541 -0.000138 -0.064524  0.000714
# 2  0.097775  1.544065  0.154688 -0.093971 -0.000254 -0.064382  0.000277
# 3  0.192551  1.557933  0.272891 -0.093605 -0.001285 -0.064611 -0.000810
# 4  0.223439  1.604338  0.313668 -0.093318 -0.000834 -0.064133 -0.000283
#
# [5 rows x 52 columns]

# %% [markdown]
# The first T-1 values of the data do not have an associated prediction, therefore they are discarded.

# %%
data = set_index(data)
mu_x = set_index(mu_x)
sigma_x = set_index(sigma_x)
print(mu_x.index[0])
data = data[mu_x.index[0]:]
data.head()
# Out:
# 2015-12-22 16:17:00
#                      FIT101      LIT101  MV101  P101  P102    AIT201  \
#  Timestamp
# 2015-12-22 16:17:00     0.0  153.026875    1.0   1.0   1.0  251.9546
# 2015-12-22 16:17:04     0.0  152.585275    1.0   1.0   1.0  251.9546
# 2015-12-22 16:17:08     0.0  151.574525    1.0   1.0   1.0  251.9546
# 2015-12-22 16:17:12     0.0  150.926850    1.0   1.0   1.0  251.9546
# 2015-12-22 16:17:16     0.0  151.201625    1.0   1.0   1.0  251.9546
#
#                        AIT202     AIT203  FIT201  MV201  ...  FIT504  P501  \
#  Timestamp                                               ...
# 2015-12-22 16:17:00  8.308640  307.83135     0.0    1.0  ...     0.0   1.0
# 2015-12-22 16:17:04  8.308640  307.86980     0.0    1.0  ...     0.0   1.0
# 2015-12-22 16:17:08  8.308640  307.99795     0.0    1.0  ...     0.0   1.0
# 2015-12-22 16:17:12  8.308640  307.97235     0.0    1.0  ...     0.0   1.0
# 2015-12-22 16:17:16  8.305435  307.92110     0.0    1.0  ...     0.0   1.0
#
#                      P502   PIT501  PIT502    PIT503    FIT601  P601  P602  \
#  Timestamp
# 2015-12-22 16:17:00   1.0  9.40464     0.0  3.716996  0.000256   1.0   1.0
# 2015-12-22 16:17:04   1.0  9.40464     0.0  3.712991  0.000256   1.0   1.0
# 2015-12-22 16:17:08   1.0  9.40464     0.0  3.668931  0.000256   1.0   1.0
# 2015-12-22 16:17:12   1.0  9.40464     0.0  3.668931  0.000256   1.0   1.0
# 2015-12-22 16:17:16   1.0  9.40464     0.0  3.668931  0.000256   1.0   1.0
#
#                      P603
#  Timestamp
# 2015-12-22 16:17:00   1.0
# 2015-12-22 16:17:04   1.0
# 2015-12-22 16:17:08   1.0
# 2015-12-22 16:17:12   1.0
# 2015-12-22 16:17:16   1.0
#
# [5 rows x 51 columns]

# %% [markdown]
# Thresholds

# %%
load_alpha = False

if load_alpha:
    with open(settings['model_name'] + '_alpha_up.pkl', 'rb') as f:
        alpha_up = pickle.load(f)
        f.close()
    with open(settings['model_name'] + '_alpha_down.pkl', 'rb') as f:
        alpha_down = pickle.load(f)
        f.close()
else:
    alpha_up = alpha_down = np.ones(len(data.columns))
    
th_up = mu_x + alpha_up*sigma_x
th_down = mu_x - alpha_down*sigma_x

# %% [markdown]
# Rescale

# %%
if settings['scale']:
    mu_x = preprocessing(mu_x, settings['scale'], None, settings['model_name'],
                         False, None, 'inverse')
    th_up = preprocessing(th_up, settings['scale'], None, settings['model_name'],
                         False, None, 'inverse')
    th_down = preprocessing(th_down, settings['scale'], None, settings['model_name'],
                         False, None, 'inverse')

# %%
mu_x.head()
# Out:
#                        FIT101      LIT101     MV101      P101      P102  \
#  Timestamp
# 2015-12-22 16:17:00  2.176028  532.578366  1.989480  1.971178  1.000987
# 2015-12-22 16:17:04  2.185410  531.043901  1.991098  1.974081  1.000988
# 2015-12-22 16:17:08  2.181712  534.216199  1.990414  1.970270  1.000947
# 2015-12-22 16:17:12  2.184420  532.263128  1.990273  1.971724  1.000558
# 2015-12-22 16:17:16  2.192084  529.708194  1.990853  1.971464  1.001087
#
#                          AIT201    AIT202      AIT203    FIT201     MV201  \
#  Timestamp
# 2015-12-22 16:17:00  268.321492  8.267853  344.260376  2.293800  1.967748
# 2015-12-22 16:17:04  268.090956  8.273885  343.609551  2.301755  1.971648
# 2015-12-22 16:17:08  268.740129  8.273432  342.251615  2.290177  1.967565
# 2015-12-22 16:17:12  268.345146  8.272770  342.899448  2.297601  1.970086
# 2015-12-22 16:17:16  267.645604  8.271215  343.557008  2.300140  1.970168
#
#                      ...    FIT504      P501      P502      PIT501    PIT502  \
#  Timestamp           ...
# 2015-12-22 16:17:00  ...  0.311506  2.000001  0.999679  255.245844  1.524412
# 2015-12-22 16:17:04  ...  0.311240  1.999953  0.999925  254.600449  1.514651
# 2015-12-22 16:17:08  ...  0.310250  1.999961  0.999602  252.713756  1.512669
# 2015-12-22 16:17:12  ...  0.310739  1.999961  1.000009  253.683742  1.515632
# 2015-12-22 16:17:16  ...  0.310932  1.999970  0.999819  253.999862  1.525548
#
#                          PIT503    FIT601      P601      P602      P603
#  Timestamp
# 2015-12-22 16:17:00  194.358620  0.000233  0.999402  0.999998  0.999907
# 2015-12-22 16:17:04  193.806526  0.000307  0.999862  0.999984  1.000714
# 2015-12-22 16:17:08  192.079628  0.000215  0.999746  0.999988  1.000277
# 2015-12-22 16:17:12  192.956274  0.000239  0.998715  0.999982  0.999190
# 2015-12-22 16:17:16  193.258700  0.000257  0.999166  0.999994  0.999717
#
# [5 rows x 51 columns]

# %%
#define number of rows and columns for subplots
nrow=20
ncol=1
 
columns_list = data.columns

time_start = '2015-12-25'
time_end = '2015-12-25 12'
fig, axes = plt.subplots(nrow, ncol, figsize=(15,30))

# plot counter
count=0

for r in range(nrow):
    for c in range(ncol):
        data[columns_list[count]][time_start:time_end].plot(ax=axes[r])
        mu_x[columns_list[count]][time_start:time_end].plot(ax=axes[r])
        axes[r].fill_between(data[columns_list[count]][time_start:time_end].index,
                         th_up[columns_list[count]][time_start:time_end],
                         th_down[columns_list[count]][time_start:time_end],
                         facecolor='orange', alpha=0.2, interpolate=True)
        count+=1
