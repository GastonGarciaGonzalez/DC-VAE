# %%
import json
import pandas as pd
from utils import preprocessing, set_index
from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras import models
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
from tensorflow.keras.models import clone_model 
from dc_vae_continual import DCVAE, Sampling
from utils import samples_conditions_embedd
import pickle
from statsmodels.graphics.tsaplots import plot_acf
# Out:
# 2023-06-22 16:40:04.111425: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
def likelihood_norm(x, mu, sigma):
    return (np.exp(-0.5*((x-mu)/sigma)**2)/(np.sqrt(2*np.pi)*sigma))/(1/(np.sqrt(2*np.pi)*sigma))

# %% [markdown]
# ### Settings

# %%
settings_path = 'settings/model_settings_continual.txt'
settings = json.load(open(settings_path, 'r'))
print(settings)
# Out:
# {'dataset_name': 'TELCO', 'model_name': 'dc-vae_continual', 'scale': False, 'wo_outliers': True, 'max_std': 7, 'T': 128, 'M': 12, 'cnn_units': [64, 128, 128, 128, 128, 128, 64], 'dil_rate': [1, 2, 4, 8, 16, 32, 64], 'kernel': 2, 'strs': 1, 'activation': 'selu', 'alpha_reg': 0.0001, 'batch_size': 32, 'J': 64, 'epochs': 200, 'lr': 0.0001, 'lr_decay': False, 'decay_rate': 0.96, 'decay_step': 7000, 'val_percent': 0.2, 'time_embedding': False, 'summary': True, 'save_best_model': False, 'save_complete_model': True}

# %% [markdown]
# ### Data

# %%
#path = '../../Datasets/TELCO/'
path = "/home/gastong/Documentos/TELCO/v1/" #Rosaluna
filenames_train = ["TELCO_data_2021_11.zip", "TELCO_data_2021_12.zip"]
files_train = [path+ i for i in filenames_train]

# Load data and predictions
# Read CSV files from List
data_train = pd.concat(map(pd.read_csv, files_train))
data_train = set_index(data_train)
data_train = preprocessing(data_train, flag_scaler=False, outliers=True)
data_train.head()
# Out:
#                           TS1       TS2       TS3       TS4       TS5  \
# time
# 2021-11-01 00:00:00  0.456788  0.361119  0.427533  0.821416  0.440503
# 2021-11-01 00:05:00  0.463067  0.361322  0.427533  0.693646  0.448490
# 2021-11-01 00:10:00  0.468363  0.340467  0.604864  0.612935  0.402251
# 2021-11-01 00:15:00  0.428095  0.327508  0.604864  0.859950  0.337353
# 2021-11-01 00:20:00  0.438827  0.326091  0.479911  1.040928  0.430928
#
#                           TS6       TS7       TS8       TS9  TS10      TS11  \
# time
# 2021-11-01 00:00:00  0.433320  0.478866  0.482249  0.087843  0.35  0.052165
# 2021-11-01 00:05:00  0.442270  0.367807  0.393491  0.087843  0.35  0.052165
# 2021-11-01 00:10:00  0.393046  0.475062  0.446746  0.087843  0.35  0.052165
# 2021-11-01 00:15:00  0.388198  0.486540  0.467456  0.113067  0.45  0.034588
# 2021-11-01 00:20:00  0.441524  0.448351  0.434911  0.113067  0.45  0.034588
#
#                          TS12
# time
# 2021-11-01 00:00:00  0.053619
# 2021-11-01 00:05:00  0.053619
# 2021-11-01 00:10:00  0.053619
# 2021-11-01 00:15:00  0.032172
# 2021-11-01 00:20:00  0.032172

# %%
#path = '../../Datasets/TELCO/'
path = "/home/gastong/Documentos/TELCO/v1/" #Rosaluna
filenames = ["TELCO_data_2022_01.zip", "TELCO_data_2022_02.zip", "TELCO_data_2022_03.zip", "TELCO_data_2022_04.zip",
                  "TELCO_data_2022_05.zip", "TELCO_data_2022_06.zip", "TELCO_data_2022_07.zip", "TELCO_data_2022_08.zip", 
                  "TELCO_data_2022_09.zip"]
files = [path+ i for i in filenames]

# %%
# Load data and predictions
# Read CSV files from List
data = pd.concat(map(pd.read_csv, files))
data = set_index(data)
data = preprocessing(data, flag_scaler=False, outliers=True)
data.head()
# Out:
#                           TS1       TS2       TS3       TS4       TS5  \
# time
# 2022-01-01 00:00:00  0.648864  0.505284  0.669942  0.837027  0.623184
# 2022-01-01 00:05:00  0.649752  0.497994  0.669942  0.820139  0.580578
# 2022-01-01 00:10:00  0.593288  0.476937  0.704539  0.777010  0.643936
# 2022-01-01 00:15:00  0.544374  0.467724  0.704539  0.835551  0.570099
# 2022-01-01 00:20:00  0.611489  0.443933  0.516019  0.795907  0.523654
#
#                           TS6       TS7       TS8       TS9   TS10      TS11  \
# time
# 2022-01-01 00:00:00  0.535870  0.634853  0.668639  0.247535  0.875  0.021380
# 2022-01-01 00:05:00  0.441524  0.590735  0.582840  0.247535  0.875  0.021380
# 2022-01-01 00:10:00  0.459797  0.548041  0.520710  0.247535  0.875  0.021380
# 2022-01-01 00:15:00  0.418404  0.556218  0.523669  0.151931  0.575  0.014328
# 2022-01-01 00:20:00  0.401623  0.632546  0.588757  0.151931  0.575  0.014328
#
#                          TS12
# time
# 2022-01-01 00:00:00  0.021448
# 2022-01-01 00:05:00  0.021448
# 2022-01-01 00:10:00  0.021448
# 2022-01-01 00:15:00  0.016086
# 2022-01-01 00:20:00  0.016086

# %%
#define number of rows and columns for subplots
nrow=12
ncol=1

columns_list = data.columns

time_start = '2022-09-01'
time_end = '2022-09-13'
fig, axes = plt.subplots(nrow, ncol, figsize=(20,30), constrained_layout=True, sharex=True)

# plot counter
count=0

for r in range(nrow):
    for c in range(ncol):
        data[columns_list[count]][time_start:time_end].plot(ax=axes[r])
        axes[r].set_title(columns_list[count])
        count+=1

# %% [markdown]
# ### Tada por task

# %%
data_train_task1 = data[:'2022-02-28']
data_test_task1 = data['2022-03-01':'2022-03-31']

data_train_task2 = data['2022-04-01':'2022-05-31']
data_test_task2 = data['2022-06-01':'2022-06-30']

data_train_task3 = data['2022-07-01':'2022-08-31']
data_test_task3 = data['2022-09-01':'2022-09-12']

# %% [markdown]
# ### CD

# %%
data_train_task1['TS1'] = 2 * data_train_task1['TS1'] 
data_test_task1['TS1'] = 2 * data_test_task1['TS1'] 

data_train_task2['TS1'] = 3 * data_train_task2['TS1'] 
data_test_task2['TS1'] = 3 * data_test_task2['TS1']  

data_train_task3['TS1'] = 4 * data_train_task3['TS1']  
data_test_task3['TS1'] = 4 * data_test_task3['TS1']
# Out:
# /tmp/ipykernel_1085260/3666605342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_task1['TS1'] = 2 * data_train_task1['TS1']
# /tmp/ipykernel_1085260/3666605342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test_task1['TS1'] = 2 * data_test_task1['TS1']
# /tmp/ipykernel_1085260/3666605342.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_task2['TS1'] = 3 * data_train_task2['TS1']
# /tmp/ipykernel_1085260/3666605342.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test_task2['TS1'] = 3 * data_test_task2['TS1']
# /tmp/ipykernel_1085260/3666605342.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_task3['TS1'] = 4 * data_train_task3['TS1']
# /tmp/ipykernel_1085260/3666605342.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test_task3['TS1'] = 4 * data_test_task3['TS1']

# %%
TS_CD = pd.concat([data_train, data_train_task1, data_test_task1, data_train_task2, data_test_task2, 
    data_train_task3, data_test_task3])

# %%
plt.figure(figsize=[20, 3])
TS_CD['TS1'].plot()
#plt.savefig('images/CD__TS1_0.png', transparent=True)
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# ## Task1

# %%
# Model initialization
model_task1 = DCVAE(
    settings['T'],
    settings['M'],
    settings['cnn_units'],
    settings['dil_rate'],
    settings['kernel'],
    settings['strs'],
    settings['batch_size'],
    settings['J'],
    settings['lr'],
    settings['lr_decay'],
    settings['decay_rate'],
    settings['decay_step'],
    settings['time_embedding'],
    settings['summary'],
    ) 

model_task1.vae = keras.models.load_model(settings['model_name']+'_complete.h5',
                                        custom_objects={'sampling': Sampling},
                                        compile = True)

# Compilation
opt = optimizers.Adam(learning_rate=settings['lr'])
model_task1.vae.compile(optimizer=opt)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method Sampling.call of <dc_vae_continual.Sampling object at 0x7fce8f0f4730>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Sampling.call of <dc_vae_continual.Sampling object at 0x7fce8f0f4730>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2023-06-22 16:40:08.201675: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-22 16:40:08.202403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-06-22 16:40:08.217711: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.217949: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA TITAN Xp computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 30 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 510.07GiB/s
# 2023-06-22 16:40:08.217967: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-22 16:40:08.219163: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-22 16:40:08.219195: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-06-22 16:40:08.220263: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-22 16:40:08.220459: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-22 16:40:08.221593: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-06-22 16:40:08.222046: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-06-22 16:40:08.224230: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-22 16:40:08.224331: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.224608: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.224702: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-06-22 16:40:08.224950: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 16:40:08.225297: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-06-22 16:40:08.225368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.225581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA TITAN Xp computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 30 deviceMemorySize: 11.91GiB deviceMemoryBandwidth: 510.07GiB/s
# 2023-06-22 16:40:08.225598: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-22 16:40:08.225613: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2023-06-22 16:40:08.225626: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2023-06-22 16:40:08.225639: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-06-22 16:40:08.225652: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-06-22 16:40:08.225665: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2023-06-22 16:40:08.225679: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2023-06-22 16:40:08.225692: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-22 16:40:08.225739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.226017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.226102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2023-06-22 16:40:08.226128: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2023-06-22 16:40:08.580181: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-06-22 16:40:08.580202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2023-06-22 16:40:08.580208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2023-06-22 16:40:08.580392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.580558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.580681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-22 16:40:08.580775: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10615 MB memory) -> physical GPU (device: 0, name: NVIDIA TITAN Xp, pci bus id: 0000:01:00.0, compute capability: 6.1)
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_samples (InputLayer)      [(None, 128, 12)]    0
# __________________________________________________________________________________________________
# dcnn_enc_0 (Conv1D)             (None, 128, 64)      1536        input_samples[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_1 (Conv1D)             (None, 128, 128)     16384       dcnn_enc_0[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_2 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_1[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_3 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_2[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_4 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_3[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_5 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_4[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_6 (Conv1D)             (None, 128, 64)      16384       dcnn_enc_5[0][0]
# __________________________________________________________________________________________________
# z_mean (Conv1D)                 (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# z_log_var (Conv1D)              (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# cropping1d (Cropping1D)         (None, 1, 64)        0           z_mean[0][0]
# __________________________________________________________________________________________________
# cropping1d_1 (Cropping1D)       (None, 1, 64)        0           z_log_var[0][0]
# __________________________________________________________________________________________________
# sampling (Sampling)             (None, None, 64)     0           cropping1d[0][0]
#                                                                  cropping1d_1[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# z_sampling_z (InputLayer)       [(None, 1, 64)]      0
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64)           0           z_sampling_z[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 128, 64)      0           reshape[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_0 (Conv1D)             (None, 128, 64)      8192        repeat_vector[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_1 (Conv1D)             (None, 128, 128)     16384       dcnn_dec_0[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_2 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_3 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_4 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_5 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_4[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_6 (Conv1D)             (None, 128, 64)      16384       dcnn_dec_5[0][0]
# __________________________________________________________________________________________________
# x__mean_output (Conv1D)         (None, 128, 12)      768         dcnn_dec_6[0][0]
# __________________________________________________________________________________________________
# x_log_var_output (Conv1D)       (None, 128, 12)      768         dcnn_dec_6[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
model_task1.fit(data_train_task1,
    settings['val_percent'],
    settings['epochs'],
    settings['model_name']+'_task1',
    settings['save_best_model'],
    False,)
# Out:
# Epoch 1/200
# 2023-06-22 16:40:09.548965: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-06-22 16:40:09.549315: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3699850000 Hz
# 2023-06-22 16:40:10.809192: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2023-06-22 16:40:11.274275: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2023-06-22 16:40:11.337837: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-06-22 16:40:11.930583: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 422/422 [==============================] - 59s 84ms/step - loss: -2.0019 - reconst: -2.2118 - kl: 0.0079 - val_loss: -2.3197 - val_reconst: -2.3200 - val_kl: 2.8562e-04
# Epoch 2/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3151 - reconst: -2.3203 - kl: 1.8684e-04 - val_loss: -2.3000 - val_reconst: -2.3002 - val_kl: 1.2955e-04
# Epoch 3/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3363 - reconst: -2.3369 - kl: 9.9268e-05 - val_loss: -2.3476 - val_reconst: -2.3476 - val_kl: 7.6414e-05
# Epoch 4/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3372 - reconst: -2.3469 - kl: 6.8841e-05 - val_loss: -2.3587 - val_reconst: -2.3587 - val_kl: 5.3567e-05
# Epoch 5/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3575 - reconst: -2.3556 - kl: 4.9240e-05 - val_loss: -2.3673 - val_reconst: -2.3673 - val_kl: 4.3779e-05
# Epoch 6/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3608 - reconst: -2.3608 - kl: 3.7013e-05 - val_loss: -2.3745 - val_reconst: -2.3745 - val_kl: 3.1389e-05
# Epoch 7/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3658 - reconst: -2.3652 - kl: 2.9933e-05 - val_loss: -2.3254 - val_reconst: -2.3254 - val_kl: 2.8996e-05
# Epoch 8/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3629 - reconst: -2.3731 - kl: 2.3713e-05 - val_loss: -2.3696 - val_reconst: -2.3697 - val_kl: 1.9675e-05
# Epoch 9/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3758 - reconst: -2.3751 - kl: 2.0501e-05 - val_loss: -2.3729 - val_reconst: -2.3729 - val_kl: 1.9576e-05
# Epoch 10/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3716 - reconst: -2.3796 - kl: 1.7692e-05 - val_loss: -2.2865 - val_reconst: -2.2865 - val_kl: 1.3853e-05
# Epoch 11/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3813 - reconst: -2.3850 - kl: 1.4449e-05 - val_loss: -2.4001 - val_reconst: -2.4001 - val_kl: 1.4994e-05
# Epoch 12/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3878 - reconst: -2.3892 - kl: 1.2736e-05 - val_loss: -2.3761 - val_reconst: -2.3761 - val_kl: 1.0805e-05
# Epoch 13/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3877 - reconst: -2.3955 - kl: 1.0923e-05 - val_loss: -2.3732 - val_reconst: -2.3732 - val_kl: 1.1904e-05
# Epoch 14/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3954 - reconst: -2.3964 - kl: 9.5671e-06 - val_loss: -2.4005 - val_reconst: -2.4005 - val_kl: 1.0831e-05
# Epoch 15/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3985 - reconst: -2.3930 - kl: 9.5061e-06 - val_loss: -2.4054 - val_reconst: -2.4054 - val_kl: 1.6149e-05
# Epoch 16/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.3935 - reconst: -2.3935 - kl: 7.8789e-06 - val_loss: -2.3871 - val_reconst: -2.3871 - val_kl: 5.2627e-06
# Epoch 17/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4007 - reconst: -2.4060 - kl: 7.4495e-06 - val_loss: -2.4023 - val_reconst: -2.4023 - val_kl: 5.5164e-06
# Epoch 18/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4078 - reconst: -2.4040 - kl: 6.1301e-06 - val_loss: -2.4095 - val_reconst: -2.4095 - val_kl: 8.8837e-06
# Epoch 19/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4154 - reconst: -2.4083 - kl: 6.0476e-06 - val_loss: -2.4069 - val_reconst: -2.4069 - val_kl: 4.5910e-06
# Epoch 20/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4159 - reconst: -2.4156 - kl: 5.8691e-06 - val_loss: -2.4103 - val_reconst: -2.4103 - val_kl: 4.0474e-06
# Epoch 21/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4112 - reconst: -2.4144 - kl: 4.7052e-06 - val_loss: -2.3733 - val_reconst: -2.3733 - val_kl: 3.6634e-06
# Epoch 22/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4074 - reconst: -2.4182 - kl: 4.4772e-06 - val_loss: -2.3989 - val_reconst: -2.3989 - val_kl: 4.9560e-06
# Epoch 23/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4122 - reconst: -2.4163 - kl: 4.7120e-06 - val_loss: -2.4379 - val_reconst: -2.4379 - val_kl: 2.9144e-06
# Epoch 24/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4107 - reconst: -2.4138 - kl: 3.8427e-06 - val_loss: -2.4228 - val_reconst: -2.4228 - val_kl: 5.7490e-06
# Epoch 25/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4291 - reconst: -2.4223 - kl: 4.1189e-06 - val_loss: -2.4262 - val_reconst: -2.4262 - val_kl: 4.3763e-06
# Epoch 26/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4282 - reconst: -2.4191 - kl: 3.4071e-06 - val_loss: -2.4243 - val_reconst: -2.4243 - val_kl: 5.6798e-06
# Epoch 27/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4291 - reconst: -2.4272 - kl: 3.4158e-06 - val_loss: -2.4132 - val_reconst: -2.4132 - val_kl: 2.9479e-06
# Epoch 28/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4227 - reconst: -2.4263 - kl: 2.8840e-06 - val_loss: -2.4271 - val_reconst: -2.4271 - val_kl: 1.7550e-06
# Epoch 29/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4288 - reconst: -2.4307 - kl: 3.3555e-06 - val_loss: -2.4232 - val_reconst: -2.4232 - val_kl: 2.9012e-06
# Epoch 30/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4264 - reconst: -2.4288 - kl: 2.6750e-06 - val_loss: -2.4096 - val_reconst: -2.4096 - val_kl: 2.8836e-06
# Epoch 31/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4277 - reconst: -2.4310 - kl: 2.6628e-06 - val_loss: -2.3844 - val_reconst: -2.3844 - val_kl: 2.0818e-06
# Epoch 32/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4397 - reconst: -2.4343 - kl: 2.7400e-06 - val_loss: -2.4371 - val_reconst: -2.4371 - val_kl: 2.5894e-06
# Epoch 33/200
# 422/422 [==============================] - 6s 14ms/step - loss: -2.4430 - reconst: -2.4372 - kl: 2.3298e-06 - val_loss: -2.4339 - val_reconst: -2.4339 - val_kl: 2.1810e-06
# Epoch 00033: early stopping

# %% [markdown]
# ### Data 0 Task 1

# %%
_, _, reconst_data0_task1, sig_data0_task1, _ = model_task1.predict(data_train,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task1'
                                                    )

# %%
likelihood_data0_task1 = likelihood_norm(data_train[settings['T']-1:], reconst_data0_task1, sig_data0_task1)
likelihood_data0_task1.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data0_task1_rest = pd.concat([likelihood_data0_task1[col] for col in likelihood_data0_task1.columns[1:]], axis=0, ignore_index=True)
likelihood_data0_task1_rest = pd.DataFrame(likelihood_data0_task1_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data0_task1_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
likelihood_data0_task1.boxplot(column=['TS1'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data 1 Task 1

# %%
_, _, reconst_data1_task1, sig_data1_task1, _ = model_task1.predict(data_test_task1,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task1'
                                                    )

# %%
likelihood_data1_task1 = likelihood_norm(data_test_task1[settings['T']-1:], reconst_data1_task1, sig_data1_task1)
likelihood_data1_task1.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data1_task1_rest = pd.concat([likelihood_data1_task1[col] for col in likelihood_data1_task1.columns[1:]], axis=0, ignore_index=True)
likelihood_data1_task1_rest = pd.DataFrame(likelihood_data1_task1_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data1_task1_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
plt.boxplot([likelihood_data0_task1_rest.values[:,0], likelihood_data1_task1_rest.values[:,0]])
plt.ylim([0.85, 1.02])
plt.title('')
plt.xticks([1, 2], ['data0_task1', 'data1_task1'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcdbc63a580>,
#   <matplotlib.axis.XTick at 0x7fcdbc63a550>],
#  [Text(1, 0, 'data0_task1'), Text(2, 0, 'data1_task1')])

# %%
_, _, reconst_all_task1, sig_all_task1, _ = model_task1.predict(TS_CD[:'2022-03-31'],
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task1'
                                                    )

# %%
th_up_all_task1 = reconst_all_task1 + sig_all_task1
th_down_all_task1 = reconst_all_task1 - sig_all_task1

plt.figure(figsize=(10,1), constrained_layout=True)


time_start = '2021-12-06'
time_end = '2022-03-31'

TS_CD['TS1'][time_start:time_end].plot()
reconst_all_task1['TS1'][time_start:time_end].plot(color='orange')
plt.fill_between(reconst_all_task1['TS1'][time_start:time_end].index,
    th_up_all_task1['TS1'][time_start:time_end],
    th_down_all_task1['TS1'][time_start:time_end],
    facecolor='orange', alpha=0.4, interpolate=True)
plt.axis('off')
# Out:
# (27312480.0, 27479515.0, -0.314374727755785, 2.760413137823343)

# %% [markdown]
# ## Task 2

# %%
# Model initialization
model_task2 = DCVAE(
    settings['T'],
    settings['M'],
    settings['cnn_units'],
    settings['dil_rate'],
    settings['kernel'],
    settings['strs'],
    settings['batch_size'],
    settings['J'],
    settings['lr'],
    settings['lr_decay'],
    settings['decay_rate'],
    settings['decay_step'],
    settings['time_embedding'],
    settings['summary'],
    ) 

model_task2.vae = clone_model(model_task1.vae)

# Compilation
opt = optimizers.Adam(learning_rate=settings['lr'])
model_task2.vae.compile(optimizer=opt)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_samples (InputLayer)      [(None, 128, 12)]    0
# __________________________________________________________________________________________________
# dcnn_enc_0 (Conv1D)             (None, 128, 64)      1536        input_samples[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_1 (Conv1D)             (None, 128, 128)     16384       dcnn_enc_0[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_2 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_1[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_3 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_2[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_4 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_3[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_5 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_4[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_6 (Conv1D)             (None, 128, 64)      16384       dcnn_enc_5[0][0]
# __________________________________________________________________________________________________
# z_mean (Conv1D)                 (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# z_log_var (Conv1D)              (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# cropping1d_2 (Cropping1D)       (None, 1, 64)        0           z_mean[0][0]
# __________________________________________________________________________________________________
# cropping1d_3 (Cropping1D)       (None, 1, 64)        0           z_log_var[0][0]
# __________________________________________________________________________________________________
# sampling_2 (Sampling)           (None, None, 64)     0           cropping1d_2[0][0]
#                                                                  cropping1d_3[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# z_sampling_z (InputLayer)       [(None, 1, 64)]      0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 64)           0           z_sampling_z[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 128, 64)      0           reshape_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_0 (Conv1D)             (None, 128, 64)      8192        repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_1 (Conv1D)             (None, 128, 128)     16384       dcnn_dec_0[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_2 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_3 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_4 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_5 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_4[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_6 (Conv1D)             (None, 128, 64)      16384       dcnn_dec_5[0][0]
# __________________________________________________________________________________________________
# x__mean_output (Conv1D)         (None, 128, 12)      768         dcnn_dec_6[0][0]
# __________________________________________________________________________________________________
# x_log_var_output (Conv1D)       (None, 128, 12)      768         dcnn_dec_6[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_task2.fit(data_train_task2,
    settings['val_percent'],
    settings['epochs'],
    settings['model_name']+'_task2',
    settings['save_best_model'],
    False)
# Out:
# Epoch 1/200
# 436/436 [==============================] - 8s 15ms/step - loss: 1.1272 - reconst: 0.1677 - kl: 0.0216 - val_loss: -0.7089 - val_reconst: -0.7134 - val_kl: 0.0045
# Epoch 2/200
# 436/436 [==============================] - 6s 14ms/step - loss: -0.9044 - reconst: -1.0651 - kl: 0.0029 - val_loss: -1.3123 - val_reconst: -1.3144 - val_kl: 0.0020
# Epoch 3/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.3687 - reconst: -1.4230 - kl: 0.0015 - val_loss: -1.5411 - val_reconst: -1.5423 - val_kl: 0.0012
# Epoch 4/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.5505 - reconst: -1.5827 - kl: 9.4095e-04 - val_loss: -1.6174 - val_reconst: -1.6182 - val_kl: 7.4449e-04
# Epoch 5/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.6596 - reconst: -1.6793 - kl: 5.9393e-04 - val_loss: -1.7196 - val_reconst: -1.7201 - val_kl: 4.9819e-04
# Epoch 6/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.7282 - reconst: -1.7515 - kl: 4.4088e-04 - val_loss: -1.7659 - val_reconst: -1.7663 - val_kl: 4.1307e-04
# Epoch 7/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.7921 - reconst: -1.8105 - kl: 3.5232e-04 - val_loss: -1.8399 - val_reconst: -1.8403 - val_kl: 3.2502e-04
# Epoch 8/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.8418 - reconst: -1.8581 - kl: 2.8841e-04 - val_loss: -1.7711 - val_reconst: -1.7714 - val_kl: 2.5267e-04
# Epoch 9/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.8755 - reconst: -1.8964 - kl: 2.3749e-04 - val_loss: -1.9338 - val_reconst: -1.9340 - val_kl: 2.2870e-04
# Epoch 10/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.9222 - reconst: -1.9324 - kl: 1.9889e-04 - val_loss: -1.9260 - val_reconst: -1.9262 - val_kl: 1.7711e-04
# Epoch 11/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.9502 - reconst: -1.9499 - kl: 1.6694e-04 - val_loss: -1.9597 - val_reconst: -1.9599 - val_kl: 1.5601e-04
# Epoch 12/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.9736 - reconst: -1.9763 - kl: 1.4537e-04 - val_loss: -2.0214 - val_reconst: -2.0216 - val_kl: 1.4386e-04
# Epoch 13/200
# 436/436 [==============================] - 6s 14ms/step - loss: -1.9989 - reconst: -1.9986 - kl: 1.2320e-04 - val_loss: -1.9941 - val_reconst: -1.9942 - val_kl: 1.1056e-04
# Epoch 14/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0161 - reconst: -2.0127 - kl: 1.0776e-04 - val_loss: -2.0301 - val_reconst: -2.0301 - val_kl: 9.3605e-05
# Epoch 15/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0253 - reconst: -2.0320 - kl: 9.4543e-05 - val_loss: -2.0522 - val_reconst: -2.0523 - val_kl: 1.0338e-04
# Epoch 16/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0427 - reconst: -2.0422 - kl: 8.1929e-05 - val_loss: -2.0903 - val_reconst: -2.0904 - val_kl: 8.4256e-05
# Epoch 17/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0576 - reconst: -2.0562 - kl: 7.3196e-05 - val_loss: -2.0699 - val_reconst: -2.0699 - val_kl: 7.0383e-05
# Epoch 18/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0610 - reconst: -2.0650 - kl: 6.4233e-05 - val_loss: -2.0885 - val_reconst: -2.0886 - val_kl: 5.3137e-05
# Epoch 19/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0634 - reconst: -2.0700 - kl: 5.8194e-05 - val_loss: -2.1092 - val_reconst: -2.1092 - val_kl: 5.2453e-05
# Epoch 20/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0855 - reconst: -2.0848 - kl: 5.1242e-05 - val_loss: -2.1156 - val_reconst: -2.1157 - val_kl: 4.0504e-05
# Epoch 21/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0907 - reconst: -2.0965 - kl: 4.6052e-05 - val_loss: -2.1347 - val_reconst: -2.1348 - val_kl: 4.6807e-05
# Epoch 22/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1039 - reconst: -2.1067 - kl: 4.2437e-05 - val_loss: -2.1270 - val_reconst: -2.1270 - val_kl: 3.7905e-05
# Epoch 23/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.0912 - reconst: -2.1035 - kl: 3.8600e-05 - val_loss: -2.0728 - val_reconst: -2.0728 - val_kl: 3.0284e-05
# Epoch 24/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1184 - reconst: -2.1229 - kl: 3.3865e-05 - val_loss: -2.0536 - val_reconst: -2.0537 - val_kl: 3.3903e-05
# Epoch 25/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1274 - reconst: -2.1298 - kl: 3.2413e-05 - val_loss: -2.1572 - val_reconst: -2.1572 - val_kl: 3.5545e-05
# Epoch 26/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1389 - reconst: -2.1411 - kl: 2.8912e-05 - val_loss: -2.0675 - val_reconst: -2.0675 - val_kl: 2.8536e-05
# Epoch 27/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1181 - reconst: -2.1286 - kl: 2.6406e-05 - val_loss: -2.1512 - val_reconst: -2.1512 - val_kl: 2.5803e-05
# Epoch 28/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1488 - reconst: -2.1504 - kl: 2.4709e-05 - val_loss: -2.1964 - val_reconst: -2.1965 - val_kl: 2.5109e-05
# Epoch 29/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1597 - reconst: -2.1551 - kl: 2.2883e-05 - val_loss: -2.1707 - val_reconst: -2.1708 - val_kl: 2.3052e-05
# Epoch 30/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1614 - reconst: -2.1608 - kl: 2.1347e-05 - val_loss: -2.0684 - val_reconst: -2.0685 - val_kl: 1.6544e-05
# Epoch 31/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1653 - reconst: -2.1651 - kl: 2.0539e-05 - val_loss: -2.2224 - val_reconst: -2.2225 - val_kl: 2.1450e-05
# Epoch 32/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1531 - reconst: -2.1649 - kl: 1.9110e-05 - val_loss: -2.1908 - val_reconst: -2.1908 - val_kl: 1.8324e-05
# Epoch 33/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1816 - reconst: -2.1738 - kl: 1.7999e-05 - val_loss: -2.1858 - val_reconst: -2.1858 - val_kl: 1.6047e-05
# Epoch 34/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1775 - reconst: -2.1821 - kl: 1.6248e-05 - val_loss: -2.1836 - val_reconst: -2.1837 - val_kl: 1.7164e-05
# Epoch 35/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1898 - reconst: -2.1858 - kl: 1.5538e-05 - val_loss: -2.1995 - val_reconst: -2.1995 - val_kl: 1.2055e-05
# Epoch 36/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1963 - reconst: -2.1912 - kl: 1.4860e-05 - val_loss: -2.1430 - val_reconst: -2.1430 - val_kl: 1.4248e-05
# Epoch 37/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1824 - reconst: -2.1864 - kl: 1.4460e-05 - val_loss: -2.2388 - val_reconst: -2.2388 - val_kl: 1.2789e-05
# Epoch 38/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2034 - reconst: -2.1995 - kl: 1.3177e-05 - val_loss: -2.2232 - val_reconst: -2.2232 - val_kl: 1.5080e-05
# Epoch 39/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2072 - reconst: -2.2046 - kl: 1.2430e-05 - val_loss: -2.2285 - val_reconst: -2.2285 - val_kl: 1.0704e-05
# Epoch 40/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.1955 - reconst: -2.2005 - kl: 1.2051e-05 - val_loss: -2.1679 - val_reconst: -2.1679 - val_kl: 1.4601e-05
# Epoch 41/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2102 - reconst: -2.2063 - kl: 1.1301e-05 - val_loss: -2.2134 - val_reconst: -2.2134 - val_kl: 9.5943e-06
# Epoch 42/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2249 - reconst: -2.2162 - kl: 1.1503e-05 - val_loss: -2.2542 - val_reconst: -2.2542 - val_kl: 9.9298e-06
# Epoch 43/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2173 - reconst: -2.2178 - kl: 1.0389e-05 - val_loss: -2.2441 - val_reconst: -2.2441 - val_kl: 1.0466e-05
# Epoch 44/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2077 - reconst: -2.2143 - kl: 1.0321e-05 - val_loss: -2.2031 - val_reconst: -2.2031 - val_kl: 8.3312e-06
# Epoch 45/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2263 - reconst: -2.2255 - kl: 9.6160e-06 - val_loss: -2.2722 - val_reconst: -2.2722 - val_kl: 9.0263e-06
# Epoch 46/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2297 - reconst: -2.2318 - kl: 9.7510e-06 - val_loss: -2.2646 - val_reconst: -2.2646 - val_kl: 1.0840e-05
# Epoch 47/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2392 - reconst: -2.2389 - kl: 8.6142e-06 - val_loss: -2.2665 - val_reconst: -2.2666 - val_kl: 1.0721e-05
# Epoch 48/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2358 - reconst: -2.2347 - kl: 8.9584e-06 - val_loss: -2.2873 - val_reconst: -2.2873 - val_kl: 9.1267e-06
# Epoch 49/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2381 - reconst: -2.2418 - kl: 8.4265e-06 - val_loss: -2.2572 - val_reconst: -2.2572 - val_kl: 9.5485e-06
# Epoch 50/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2438 - reconst: -2.2420 - kl: 7.8795e-06 - val_loss: -2.2433 - val_reconst: -2.2433 - val_kl: 9.6847e-06
# Epoch 51/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2462 - reconst: -2.2459 - kl: 7.8352e-06 - val_loss: -2.2584 - val_reconst: -2.2584 - val_kl: 9.0453e-06
# Epoch 52/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2471 - reconst: -2.2469 - kl: 7.8565e-06 - val_loss: -2.2463 - val_reconst: -2.2463 - val_kl: 5.3451e-06
# Epoch 53/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2423 - reconst: -2.2514 - kl: 7.3453e-06 - val_loss: -2.2846 - val_reconst: -2.2846 - val_kl: 5.3986e-06
# Epoch 54/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2627 - reconst: -2.2587 - kl: 7.1471e-06 - val_loss: -2.2903 - val_reconst: -2.2903 - val_kl: 4.7825e-06
# Epoch 55/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2557 - reconst: -2.2613 - kl: 6.8116e-06 - val_loss: -2.1977 - val_reconst: -2.1977 - val_kl: 5.6587e-06
# Epoch 56/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2500 - reconst: -2.2575 - kl: 6.7802e-06 - val_loss: -2.3032 - val_reconst: -2.3032 - val_kl: 8.2300e-06
# Epoch 57/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2534 - reconst: -2.2588 - kl: 6.2528e-06 - val_loss: -2.2802 - val_reconst: -2.2802 - val_kl: 7.4031e-06
# Epoch 58/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2662 - reconst: -2.2636 - kl: 6.1479e-06 - val_loss: -2.2858 - val_reconst: -2.2858 - val_kl: 7.1297e-06
# Epoch 59/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2696 - reconst: -2.2654 - kl: 6.1789e-06 - val_loss: -2.2688 - val_reconst: -2.2688 - val_kl: 5.5557e-06
# Epoch 60/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2771 - reconst: -2.2710 - kl: 5.8162e-06 - val_loss: -2.3158 - val_reconst: -2.3158 - val_kl: 5.9134e-06
# Epoch 61/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2874 - reconst: -2.2835 - kl: 5.8009e-06 - val_loss: -2.3006 - val_reconst: -2.3006 - val_kl: 6.3408e-06
# Epoch 62/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2668 - reconst: -2.2731 - kl: 5.7328e-06 - val_loss: -2.2960 - val_reconst: -2.2960 - val_kl: 7.2556e-06
# Epoch 63/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2744 - reconst: -2.2742 - kl: 5.3417e-06 - val_loss: -2.3219 - val_reconst: -2.3219 - val_kl: 5.6661e-06
# Epoch 64/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2819 - reconst: -2.2819 - kl: 5.3929e-06 - val_loss: -2.2146 - val_reconst: -2.2147 - val_kl: 6.2598e-06
# Epoch 65/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2747 - reconst: -2.2819 - kl: 5.1189e-06 - val_loss: -2.3232 - val_reconst: -2.3232 - val_kl: 4.3530e-06
# Epoch 66/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2880 - reconst: -2.2865 - kl: 5.0143e-06 - val_loss: -2.3199 - val_reconst: -2.3199 - val_kl: 4.3819e-06
# Epoch 67/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2898 - reconst: -2.2890 - kl: 5.0720e-06 - val_loss: -2.3052 - val_reconst: -2.3052 - val_kl: 4.1210e-06
# Epoch 68/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2884 - reconst: -2.2935 - kl: 4.6708e-06 - val_loss: -2.1859 - val_reconst: -2.1859 - val_kl: 4.1344e-06
# Epoch 69/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.2726 - reconst: -2.2858 - kl: 4.8138e-06 - val_loss: -2.3119 - val_reconst: -2.3119 - val_kl: 4.0898e-06
# Epoch 70/200
# 436/436 [==============================] - 6s 14ms/step - loss: -2.3051 - reconst: -2.2992 - kl: 4.7347e-06 - val_loss: -2.3165 - val_reconst: -2.3165 - val_kl: 4.2573e-06
# Epoch 00070: early stopping

# %% [markdown]
# ### Data 0 Task 2

# %%
_, _, reconst_data0_task2, sig_data0_task2, _ = model_task2.predict(data_train,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
likelihood_data0_task2 = likelihood_norm(data_train[settings['T']-1:], reconst_data0_task2, sig_data0_task2)
likelihood_data0_task2.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data0_task2_rest = pd.concat([likelihood_data0_task2[col] for col in likelihood_data0_task2.columns[1:]], axis=0, ignore_index=True)
likelihood_data0_task2_rest = pd.DataFrame(likelihood_data0_task2_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data0_task2_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 1 Task 2

# %%
_, _, reconst_data1_task2, sig_data1_task2, _ = model_task2.predict(data_test_task1,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
likelihood_data1_task2 = likelihood_norm(data_test_task1[settings['T']-1:], reconst_data1_task2, sig_data1_task2)
likelihood_data1_task2.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data1_task2_rest = pd.concat([likelihood_data1_task2[col] for col in likelihood_data1_task2.columns[1:]], axis=0, ignore_index=True)
likelihood_data1_task2_rest = pd.DataFrame(likelihood_data1_task2_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data1_task2_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 2 Task 2

# %%
_, _, reconst_data2_task2, sig_data2_task2, _ = model_task2.predict(data_test_task2,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
likelihood_data2_task2 = likelihood_norm(data_test_task2[settings['T']-1:], reconst_data2_task2, sig_data2_task2)
likelihood_data2_task2.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data2_task2_rest = pd.concat([likelihood_data2_task2[col] for col in likelihood_data2_task2.columns[1:]], axis=0, ignore_index=True)
likelihood_data2_task2_rest = pd.DataFrame(likelihood_data2_task2_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data2_task2_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
plt.boxplot([likelihood_data0_task2_rest.values[:,0], likelihood_data1_task2_rest.values[:,0], likelihood_data2_task2_rest.values[:,0]])
plt.ylim([0.85, 1.02])
plt.title('')
plt.xticks([1, 2, 3], ['data0_task2', 'data1_task2', 'data2_task2'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcaebebb5e0>,
#   <matplotlib.axis.XTick at 0x7fcaebebb8e0>,
#   <matplotlib.axis.XTick at 0x7fcaebedcdf0>],
#  [Text(1, 0, 'data0_task2'),
#   Text(2, 0, 'data1_task2'),
#   Text(3, 0, 'data2_task2')])

# %%
plt.boxplot([likelihood_data0_task2['TS1'].values, likelihood_data1_task2['TS1'].values, likelihood_data2_task2['TS1'].values])
plt.title('')
plt.xticks([1, 2, 3], ['data0_task2', 'data1_task2', 'data2_task2'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcaebe49640>,
#   <matplotlib.axis.XTick at 0x7fcaebe49610>,
#   <matplotlib.axis.XTick at 0x7fcaebe6c670>],
#  [Text(1, 0, 'data0_task2'),
#   Text(2, 0, 'data1_task2'),
#   Text(3, 0, 'data2_task2')])

# %%
_, _, reconst_all_task2, sig_all_task2, _ = model_task2.predict(TS_CD[:'2022-06-30'],
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
th_up_all_task2 = reconst_all_task2 + sig_all_task2
th_down_all_task2 = reconst_all_task2 - sig_all_task2

plt.figure(figsize=(10,1), constrained_layout=True)


time_start = '2021-12-06'
time_end = '2022-06-30'

TS_CD['TS1'][time_start:time_end].plot()
reconst_all_task2['TS1'][time_start:time_end].plot(color='orange')
plt.fill_between(reconst_all_task2['TS1'][time_start:time_end].index,
    th_up_all_task2['TS1'][time_start:time_end],
    th_down_all_task2['TS1'][time_start:time_end],
    facecolor='orange', alpha=0.4, interpolate=True)
plt.axis('off')
#plt.savefig('images/GR/CD_real_TELCO.png', transparent=True)
# Out:
# (27312480.0, 27610555.0, -0.7937861233949661, 3.1702230125665665)

# %% [markdown]
# ## Task 3

# %%
# Model initialization
model_task3 = DCVAE(
    settings['T'],
    settings['M'],
    settings['cnn_units'],
    settings['dil_rate'],
    settings['kernel'],
    settings['strs'],
    settings['batch_size'],
    settings['J'],
    settings['lr'],
    settings['lr_decay'],
    settings['decay_rate'],
    settings['decay_step'],
    settings['time_embedding'],
    settings['summary'],
    ) 

model_task3.vae = clone_model(model_task2.vae)

# Compilation
opt = optimizers.Adam(learning_rate=settings['lr'])
model_task3.vae.compile(optimizer=opt)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_samples (InputLayer)      [(None, 128, 12)]    0
# __________________________________________________________________________________________________
# dcnn_enc_0 (Conv1D)             (None, 128, 64)      1536        input_samples[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_1 (Conv1D)             (None, 128, 128)     16384       dcnn_enc_0[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_2 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_1[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_3 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_2[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_4 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_3[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_5 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_4[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_6 (Conv1D)             (None, 128, 64)      16384       dcnn_enc_5[0][0]
# __________________________________________________________________________________________________
# z_mean (Conv1D)                 (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# z_log_var (Conv1D)              (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# cropping1d_4 (Cropping1D)       (None, 1, 64)        0           z_mean[0][0]
# __________________________________________________________________________________________________
# cropping1d_5 (Cropping1D)       (None, 1, 64)        0           z_log_var[0][0]
# __________________________________________________________________________________________________
# sampling_4 (Sampling)           (None, None, 64)     0           cropping1d_4[0][0]
#                                                                  cropping1d_5[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# z_sampling_z (InputLayer)       [(None, 1, 64)]      0
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 64)           0           z_sampling_z[0][0]
# __________________________________________________________________________________________________
# repeat_vector_2 (RepeatVector)  (None, 128, 64)      0           reshape_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_0 (Conv1D)             (None, 128, 64)      8192        repeat_vector_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_1 (Conv1D)             (None, 128, 128)     16384       dcnn_dec_0[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_2 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_3 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_4 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_5 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_4[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_6 (Conv1D)             (None, 128, 64)      16384       dcnn_dec_5[0][0]
# __________________________________________________________________________________________________
# x__mean_output (Conv1D)         (None, 128, 12)      768         dcnn_dec_6[0][0]
# __________________________________________________________________________________________________
# x_log_var_output (Conv1D)       (None, 128, 12)      768         dcnn_dec_6[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_task3.fit(data_train_task3,
    settings['val_percent'],
    settings['epochs'],
    settings['model_name']+'_task3',
    settings['save_best_model'],
    False)
# Out:
# Epoch 1/200
# 444/444 [==============================] - 40s 87ms/step - loss: 0.9329 - reconst: -7.6796e-04 - kl: 0.0188 - val_loss: -0.7607 - val_reconst: -0.7649 - val_kl: 0.0042
# Epoch 2/200
# 444/444 [==============================] - 6s 14ms/step - loss: -0.9086 - reconst: -1.0312 - kl: 0.0027 - val_loss: -1.2389 - val_reconst: -1.2409 - val_kl: 0.0020
# Epoch 3/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.3020 - reconst: -1.3620 - kl: 0.0014 - val_loss: -1.4936 - val_reconst: -1.4947 - val_kl: 0.0011
# Epoch 4/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.5245 - reconst: -1.5644 - kl: 8.2412e-04 - val_loss: -1.6339 - val_reconst: -1.6346 - val_kl: 7.4313e-04
# Epoch 5/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.6534 - reconst: -1.6814 - kl: 5.1947e-04 - val_loss: -1.6893 - val_reconst: -1.6898 - val_kl: 4.4559e-04
# Epoch 6/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.7395 - reconst: -1.7638 - kl: 3.9441e-04 - val_loss: -1.7344 - val_reconst: -1.7348 - val_kl: 3.7423e-04
# Epoch 7/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.7930 - reconst: -1.8050 - kl: 3.1409e-04 - val_loss: -1.8127 - val_reconst: -1.8130 - val_kl: 3.1969e-04
# Epoch 8/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.8564 - reconst: -1.8644 - kl: 2.5997e-04 - val_loss: -1.8228 - val_reconst: -1.8231 - val_kl: 2.5534e-04
# Epoch 9/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.8840 - reconst: -1.8925 - kl: 2.2234e-04 - val_loss: -1.8520 - val_reconst: -1.8522 - val_kl: 2.4793e-04
# Epoch 10/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.9004 - reconst: -1.9182 - kl: 1.8369e-04 - val_loss: -1.8908 - val_reconst: -1.8910 - val_kl: 1.8952e-04
# Epoch 11/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.9373 - reconst: -1.9434 - kl: 1.5540e-04 - val_loss: -1.9664 - val_reconst: -1.9665 - val_kl: 1.3639e-04
# Epoch 12/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.9568 - reconst: -1.9611 - kl: 1.3522e-04 - val_loss: -1.9756 - val_reconst: -1.9757 - val_kl: 1.2568e-04
# Epoch 13/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.9684 - reconst: -1.9772 - kl: 1.1704e-04 - val_loss: -1.9940 - val_reconst: -1.9941 - val_kl: 1.4600e-04
# Epoch 14/200
# 444/444 [==============================] - 6s 14ms/step - loss: -1.9993 - reconst: -2.0020 - kl: 9.8672e-05 - val_loss: -2.0112 - val_reconst: -2.0113 - val_kl: 9.6904e-05
# Epoch 15/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0003 - reconst: -2.0034 - kl: 8.8843e-05 - val_loss: -1.9893 - val_reconst: -1.9894 - val_kl: 8.8023e-05
# Epoch 16/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0135 - reconst: -2.0209 - kl: 7.8195e-05 - val_loss: -2.0413 - val_reconst: -2.0414 - val_kl: 7.7961e-05
# Epoch 17/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0343 - reconst: -2.0339 - kl: 6.9322e-05 - val_loss: -2.0508 - val_reconst: -2.0509 - val_kl: 8.0967e-05
# Epoch 18/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.0532 - reconst: -2.0536 - kl: 6.1554e-05 - val_loss: -2.0563 - val_reconst: -2.0563 - val_kl: 7.2068e-05
# Epoch 19/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0546 - reconst: -2.0590 - kl: 5.4976e-05 - val_loss: -2.0515 - val_reconst: -2.0516 - val_kl: 7.8958e-05
# Epoch 20/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0645 - reconst: -2.0616 - kl: 4.8666e-05 - val_loss: -2.0645 - val_reconst: -2.0646 - val_kl: 4.5924e-05
# Epoch 21/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0774 - reconst: -2.0737 - kl: 4.6015e-05 - val_loss: -2.0744 - val_reconst: -2.0745 - val_kl: 8.1746e-05
# Epoch 22/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0837 - reconst: -2.0752 - kl: 4.0299e-05 - val_loss: -2.0941 - val_reconst: -2.0942 - val_kl: 4.7654e-05
# Epoch 23/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.0975 - reconst: -2.0980 - kl: 3.7321e-05 - val_loss: -2.1205 - val_reconst: -2.1205 - val_kl: 5.3053e-05
# Epoch 24/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.1007 - reconst: -2.1012 - kl: 3.4229e-05 - val_loss: -2.1263 - val_reconst: -2.1264 - val_kl: 3.3028e-05
# Epoch 25/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.0982 - reconst: -2.0951 - kl: 3.0386e-05 - val_loss: -2.1265 - val_reconst: -2.1265 - val_kl: 3.4290e-05
# Epoch 26/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1112 - reconst: -2.1115 - kl: 2.9063e-05 - val_loss: -2.1233 - val_reconst: -2.1233 - val_kl: 5.6931e-05
# Epoch 27/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1247 - reconst: -2.1240 - kl: 2.6784e-05 - val_loss: -2.1281 - val_reconst: -2.1281 - val_kl: 3.1330e-05
# Epoch 28/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.1301 - reconst: -2.1299 - kl: 2.4964e-05 - val_loss: -2.0521 - val_reconst: -2.0521 - val_kl: 2.9351e-05
# Epoch 29/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1219 - reconst: -2.1271 - kl: 2.4520e-05 - val_loss: -2.1611 - val_reconst: -2.1612 - val_kl: 2.2488e-05
# Epoch 30/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1367 - reconst: -2.1382 - kl: 2.0968e-05 - val_loss: -2.1582 - val_reconst: -2.1582 - val_kl: 3.5048e-05
# Epoch 31/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1370 - reconst: -2.1346 - kl: 2.0894e-05 - val_loss: -2.1321 - val_reconst: -2.1322 - val_kl: 1.8235e-05
# Epoch 32/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1491 - reconst: -2.1484 - kl: 1.9299e-05 - val_loss: -2.0598 - val_reconst: -2.0598 - val_kl: 1.6340e-05
# Epoch 33/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1388 - reconst: -2.1472 - kl: 1.8854e-05 - val_loss: -2.1499 - val_reconst: -2.1499 - val_kl: 1.8739e-05
# Epoch 34/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1604 - reconst: -2.1592 - kl: 1.7499e-05 - val_loss: -2.1851 - val_reconst: -2.1851 - val_kl: 2.3104e-05
# Epoch 35/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1624 - reconst: -2.1626 - kl: 1.6618e-05 - val_loss: -2.1751 - val_reconst: -2.1751 - val_kl: 1.9219e-05
# Epoch 36/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1533 - reconst: -2.1587 - kl: 1.5514e-05 - val_loss: -2.1495 - val_reconst: -2.1495 - val_kl: 1.9304e-05
# Epoch 37/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1505 - reconst: -2.1635 - kl: 1.5122e-05 - val_loss: -2.1814 - val_reconst: -2.1814 - val_kl: 1.9488e-05
# Epoch 38/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1758 - reconst: -2.1721 - kl: 1.4294e-05 - val_loss: -2.1458 - val_reconst: -2.1458 - val_kl: 1.9557e-05
# Epoch 39/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1527 - reconst: -2.1617 - kl: 1.3679e-05 - val_loss: -2.1845 - val_reconst: -2.1845 - val_kl: 2.1133e-05
# Epoch 40/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1708 - reconst: -2.1739 - kl: 1.2683e-05 - val_loss: -2.1911 - val_reconst: -2.1911 - val_kl: 1.0506e-05
# Epoch 41/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.1866 - reconst: -2.1770 - kl: 1.1979e-05 - val_loss: -2.1732 - val_reconst: -2.1732 - val_kl: 1.1295e-05
# Epoch 42/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1820 - reconst: -2.1838 - kl: 1.2844e-05 - val_loss: -2.1951 - val_reconst: -2.1951 - val_kl: 2.0792e-05
# Epoch 43/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1916 - reconst: -2.1896 - kl: 1.1551e-05 - val_loss: -2.2213 - val_reconst: -2.2213 - val_kl: 1.3861e-05
# Epoch 44/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1974 - reconst: -2.1945 - kl: 1.0932e-05 - val_loss: -2.1764 - val_reconst: -2.1764 - val_kl: 1.4508e-05
# Epoch 45/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2080 - reconst: -2.1998 - kl: 1.1095e-05 - val_loss: -2.1950 - val_reconst: -2.1951 - val_kl: 1.5041e-05
# Epoch 46/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1976 - reconst: -2.1987 - kl: 1.0162e-05 - val_loss: -2.1197 - val_reconst: -2.1197 - val_kl: 1.2166e-05
# Epoch 47/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.1892 - reconst: -2.1990 - kl: 9.7485e-06 - val_loss: -2.2282 - val_reconst: -2.2282 - val_kl: 1.2115e-05
# Epoch 48/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2060 - reconst: -2.2024 - kl: 9.6835e-06 - val_loss: -2.1101 - val_reconst: -2.1101 - val_kl: 2.2857e-05
# Epoch 49/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2030 - reconst: -2.2121 - kl: 9.0845e-06 - val_loss: -2.2243 - val_reconst: -2.2243 - val_kl: 1.0125e-05
# Epoch 50/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2136 - reconst: -2.2110 - kl: 8.9405e-06 - val_loss: -2.2358 - val_reconst: -2.2358 - val_kl: 7.7480e-06
# Epoch 51/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2070 - reconst: -2.2113 - kl: 8.8424e-06 - val_loss: -2.2306 - val_reconst: -2.2306 - val_kl: 1.9417e-05
# Epoch 52/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2250 - reconst: -2.2186 - kl: 8.2721e-06 - val_loss: -2.2303 - val_reconst: -2.2303 - val_kl: 8.1796e-06
# Epoch 53/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2206 - reconst: -2.2195 - kl: 8.3031e-06 - val_loss: -2.1565 - val_reconst: -2.1565 - val_kl: 7.8219e-06
# Epoch 54/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2215 - reconst: -2.2200 - kl: 7.8726e-06 - val_loss: -2.2348 - val_reconst: -2.2348 - val_kl: 2.0901e-05
# Epoch 55/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2293 - reconst: -2.2225 - kl: 7.3426e-06 - val_loss: -2.1856 - val_reconst: -2.1856 - val_kl: 6.0432e-06
# Epoch 56/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2289 - reconst: -2.2281 - kl: 7.7028e-06 - val_loss: -2.2443 - val_reconst: -2.2443 - val_kl: 7.3439e-06
# Epoch 57/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2134 - reconst: -2.2232 - kl: 7.1109e-06 - val_loss: -2.2365 - val_reconst: -2.2365 - val_kl: 5.5181e-06
# Epoch 58/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2274 - reconst: -2.2339 - kl: 7.0731e-06 - val_loss: -2.1604 - val_reconst: -2.1604 - val_kl: 6.4958e-06
# Epoch 59/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2133 - reconst: -2.2275 - kl: 6.6709e-06 - val_loss: -2.2354 - val_reconst: -2.2354 - val_kl: 6.5195e-06
# Epoch 60/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2317 - reconst: -2.2358 - kl: 6.7726e-06 - val_loss: -2.2406 - val_reconst: -2.2407 - val_kl: 1.5198e-05
# Epoch 00060: early stopping

# %% [markdown]
# ### Data 0 Task 3

# %%
_, _, reconst_data0_task3, sig_data0_task3, _ = model_task3.predict(data_train,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data0_task3 = likelihood_norm(data_train[settings['T']-1:], reconst_data0_task3, sig_data0_task3)
likelihood_data0_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data0_task3_rest = pd.concat([likelihood_data0_task3[col] for col in likelihood_data0_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data0_task3_rest = pd.DataFrame(likelihood_data0_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data0_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 1 Task 3

# %%
_, _, reconst_data1_task3, sig_data1_task3, _ = model_task3.predict(data_test_task1,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data1_task3 = likelihood_norm(data_test_task1[settings['T']-1:], reconst_data1_task3, sig_data1_task3)
likelihood_data1_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data1_task3_rest = pd.concat([likelihood_data1_task3[col] for col in likelihood_data1_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data1_task3_rest = pd.DataFrame(likelihood_data1_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data1_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 2 Task 3

# %%
_, _, reconst_data2_task3, sig_data2_task3, _ = model_task3.predict(data_test_task2,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data2_task3 = likelihood_norm(data_test_task2[settings['T']-1:], reconst_data2_task3, sig_data2_task3)
likelihood_data2_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data2_task3_rest = pd.concat([likelihood_data2_task3[col] for col in likelihood_data2_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data2_task3_rest = pd.DataFrame(likelihood_data2_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data2_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 3 Task 3

# %%
_, _, reconst_data3_task3, sig_data3_task3, _ = model_task3.predict(data_test_task3,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data3_task3 = likelihood_norm(data_test_task3[settings['T']-1:], reconst_data3_task3, sig_data3_task3)
likelihood_data3_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data3_task3_rest = pd.concat([likelihood_data3_task3[col] for col in likelihood_data3_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data3_task3_rest = pd.DataFrame(likelihood_data3_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data3_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
plt.boxplot([likelihood_data0_task3_rest.values[:,0], likelihood_data1_task3_rest.values[:,0], likelihood_data2_task3_rest.values[:,0], likelihood_data3_task3_rest.values[:,0]])
plt.ylim([0.85, 1.02])
plt.title('')
plt.xticks([1, 2, 3, 4], ['data0_task3', 'data1_task3', 'data2_task3', 'data3_task3'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcae83cf790>,
#   <matplotlib.axis.XTick at 0x7fcae83cf760>,
#   <matplotlib.axis.XTick at 0x7fcae8372670>,
#   <matplotlib.axis.XTick at 0x7fcae8333be0>],
#  [Text(1, 0, 'data0_task3'),
#   Text(2, 0, 'data1_task3'),
#   Text(3, 0, 'data2_task3'),
#   Text(4, 0, 'data3_task3')])

# %%
plt.boxplot([likelihood_data0_task3['TS1'].values, likelihood_data1_task3['TS1'].values, likelihood_data2_task3['TS1'].values, likelihood_data3_task3['TS1'].values],
 notch=True,
 bootstrap=5000)
plt.title('')
plt.xticks([1, 2, 3, 4], ['data0_task3', 'data1_task3', 'data2_task3', 'data3_task3'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcae82f1f10>,
#   <matplotlib.axis.XTick at 0x7fcae82f1ee0>,
#   <matplotlib.axis.XTick at 0x7fcae8315d30>,
#   <matplotlib.axis.XTick at 0x7fcae82dd310>],
#  [Text(1, 0, 'data0_task3'),
#   Text(2, 0, 'data1_task3'),
#   Text(3, 0, 'data2_task3'),
#   Text(4, 0, 'data3_task3')])

# %%
likelihood_data0_task3['TS1'].shape
# Out:
# (17441,)

# %%
#define number of rows and columns for subplots
nrow=3
ncol=4

fig, axes = plt.subplots(nrow, ncol, constrained_layout=True, sharey=True)

axes[0,0].boxplot(likelihood_data0_task1['TS1'].values)
axes[0,0].set_title('Data 0')
axes[0,0].set_ylabel('Task 1')
axes[0,1].boxplot(likelihood_data1_task1['TS1'].values)
axes[0,1].set_title('Data 1')
axes[0,2].axis('off')
axes[0,2].set_title('Data 2')
axes[0,3].axis('off')
axes[0,3].set_title('Data 3')


axes[1,0].boxplot(likelihood_data0_task2['TS1'].values)
axes[1,0].set_ylabel('Task 2')
axes[1,1].boxplot(likelihood_data1_task2['TS1'].values)
axes[1,2].boxplot(likelihood_data2_task2['TS1'].values)
axes[1,3].axis('off')

axes[2,0].boxplot(likelihood_data0_task3['TS1'].values)
axes[2,0].set_ylabel('Task 3')
axes[2,1].boxplot(likelihood_data1_task3['TS1'].values)
axes[2,2].boxplot(likelihood_data2_task3['TS1'].values)
axes[2,3].boxplot(likelihood_data3_task3['TS1'].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcadbf72610>,
#   <matplotlib.lines.Line2D at 0x7fcadbf728e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fcadbf72bb0>,
#   <matplotlib.lines.Line2D at 0x7fcadbf72e80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcadbf72340>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcadbf7a190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcadbf7a460>],
#  'means': []}

# %%
likelihood_data0_task1.to_csv('likelihood_data0_task1_noGR.csv')
likelihood_data1_task1.to_csv('likelihood_data1_task1_noGR.csv')

likelihood_data0_task2.to_csv('likelihood_data0_task2_noGR.csv')
likelihood_data1_task2.to_csv('likelihood_data1_task2_noGR.csv')
likelihood_data2_task2.to_csv('likelihood_data2_task2_noGR.csv')

likelihood_data0_task3.to_csv('likelihood_data0_task3_noGR.csv')
likelihood_data1_task3.to_csv('likelihood_data1_task3_noGR.csv')
likelihood_data2_task3.to_csv('likelihood_data2_task3_noGR.csv')
likelihood_data3_task3.to_csv('likelihood_data3_task3_noGR.csv')

# %%
#define number of rows and columns for subplots
nrow=3
ncol=4

fig, axes = plt.subplots(nrow, ncol, constrained_layout=True, sharey=True)

axes[0,0].boxplot(likelihood_data0_task1_rest.values[:,0])
axes[0,0].set_title('Data 0')
axes[0,0].set_ylabel('Task 1')
axes[0,1].boxplot(likelihood_data1_task1_rest.values[:,0])
axes[0,1].set_title('Data 1')
axes[0,2].axis('off')
axes[0,2].set_title('Data 2')
axes[0,3].axis('off')
axes[0,3].set_title('Data 3')


axes[1,0].boxplot(likelihood_data0_task2_rest.values[:,0])
axes[1,0].set_ylabel('Task 2')
axes[1,1].boxplot(likelihood_data1_task2_rest.values[:,0])
axes[1,2].boxplot(likelihood_data2_task2_rest.values[:,0])
axes[1,3].axis('off')

axes[2,0].boxplot(likelihood_data0_task3_rest.values[:,0])
axes[2,0].set_ylabel('Task 3')
axes[2,1].boxplot(likelihood_data1_task3_rest.values[:,0])
axes[2,2].boxplot(likelihood_data2_task3_rest.values[:,0])
axes[2,3].boxplot(likelihood_data3_task3_rest.values[:,0])

plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
likelihood_data0_task1_GR = pd.read_csv('likelihood_data0_task1_GR.csv')
likelihood_data1_task1_GR = pd.read_csv('likelihood_data1_task1_GR.csv')

likelihood_data0_task2_GR = pd.read_csv('likelihood_data0_task2_GR.csv')
likelihood_data1_task2_GR = pd.read_csv('likelihood_data1_task2_GR.csv')
likelihood_data2_task2_GR = pd.read_csv('likelihood_data2_task2_GR.csv')

likelihood_data0_task3_GR = pd.read_csv('likelihood_data0_task3_GR.csv')
likelihood_data1_task3_GR = pd.read_csv('likelihood_data1_task3_GR.csv')
likelihood_data2_task3_GR = pd.read_csv('likelihood_data2_task3_GR.csv')
likelihood_data3_task3_GR = pd.read_csv('likelihood_data3_task3_GR.csv')

likelihood_data0_task1_noGR = pd.read_csv('likelihood_data0_task1_noGR.csv')
likelihood_data1_task1_noGR = pd.read_csv('likelihood_data1_task1_noGR.csv')

likelihood_data0_task2_noGR = pd.read_csv('likelihood_data0_task2_noGR.csv')
likelihood_data1_task2_noGR = pd.read_csv('likelihood_data1_task2_noGR.csv')
likelihood_data2_task2_noGR = pd.read_csv('likelihood_data2_task2_noGR.csv')

likelihood_data0_task3_noGR = pd.read_csv('likelihood_data0_task3_noGR.csv')
likelihood_data1_task3_noGR = pd.read_csv('likelihood_data1_task3_noGR.csv')
likelihood_data2_task3_noGR = pd.read_csv('likelihood_data2_task3_noGR.csv')
likelihood_data3_task3_noGR = pd.read_csv('likelihood_data3_task3_noGR.csv')

# %%
#define number of rows and columns for subplots
nrow=3
ncol=4

fig, axes = plt.subplots(nrow, ncol, constrained_layout=True, sharey=True, sharex=True)

axes[0,0].boxplot([likelihood_data0_task1_noGR['TS1'].values,
                   likelihood_data0_task1_GR['TS1'].values])
axes[0,0].set_title(r'$S_{t-1}$')
axes[0,0].set_ylabel('Task 1')
axes[0,1].boxplot([likelihood_data1_task1_noGR['TS1'].values,
                  likelihood_data1_task1_GR['TS1'].values])
axes[0,1].set_title(r'$S_{t}$')
axes[0,2].axis('off')
axes[0,2].set_title(r'$S_{t+1}$')
axes[0,3].axis('off')
axes[0,3].set_title(r'$S_{t+2}$')


axes[1,0].boxplot([likelihood_data0_task2_noGR['TS1'].values,
                  likelihood_data0_task2_GR['TS1'].values])
axes[1,0].set_ylabel('Task 2')
axes[1,1].boxplot([likelihood_data1_task2_noGR['TS1'].values,
                  likelihood_data1_task2_GR['TS1'].values])
axes[1,2].boxplot([likelihood_data2_task2_noGR['TS1'].values,
                  likelihood_data2_task2_GR['TS1'].values])
axes[1,3].axis('off')

axes[2,0].boxplot([likelihood_data0_task3_noGR['TS1'].values,
                  likelihood_data0_task3_GR['TS1'].values])
axes[2,0].set_ylabel('Task 3')
axes[2,1].boxplot([likelihood_data1_task3_noGR['TS1'].values,
                  likelihood_data1_task3_GR['TS1'].values])

axes[2,2].boxplot([likelihood_data2_task3_noGR['TS1'].values,
                  likelihood_data2_task3_GR['TS1'].values])

axes[2,3].boxplot([likelihood_data3_task3_noGR['TS1'].values,
                  likelihood_data3_task3_GR['TS1'].values])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fcadbc51ac0>,
#   <matplotlib.lines.Line2D at 0x7fcadbc51d90>,
#   <matplotlib.lines.Line2D at 0x7fcadbc5eeb0>,
#   <matplotlib.lines.Line2D at 0x7fcadbc6d1c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fcadbc5e0a0>,
#   <matplotlib.lines.Line2D at 0x7fcadbc5e370>,
#   <matplotlib.lines.Line2D at 0x7fcadbc6d490>,
#   <matplotlib.lines.Line2D at 0x7fcadbc6d760>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fcadbc517f0>,
#   <matplotlib.lines.Line2D at 0x7fcadbc5ebe0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fcadbc5e640>,
#   <matplotlib.lines.Line2D at 0x7fcadbc6da30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fcadbc5e910>,
#   <matplotlib.lines.Line2D at 0x7fcadbc6dd00>],
#  'means': []}
