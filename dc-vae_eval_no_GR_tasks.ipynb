# %%
import json
import pandas as pd
from utils import preprocessing, set_index
from matplotlib import pyplot as plt
import numpy as np
from tensorflow.keras import models
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
from dc_vae_continual import DCVAE, Sampling
from utils import samples_conditions_embedd
import pickle
from statsmodels.graphics.tsaplots import plot_acf
# Out:
# 2023-06-14 12:40:11.658394: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
def likelihood_norm(x, mu, sigma):
    return (np.exp(-0.5*((x-mu)/sigma)**2)/(np.sqrt(2*np.pi)*sigma))/(1/(np.sqrt(2*np.pi)*sigma))

# %% [markdown]
# ### Settings

# %%
settings_path = 'settings/model_settings_continual.txt'
settings = json.load(open(settings_path, 'r'))
print(settings)
# Out:
# {'dataset_name': 'TELCO', 'model_name': 'dc-vae_continual', 'scale': False, 'wo_outliers': True, 'max_std': 7, 'T': 128, 'M': 12, 'cnn_units': [64, 128, 128, 128, 128, 128, 64], 'dil_rate': [1, 2, 4, 8, 16, 32, 64], 'kernel': 2, 'strs': 1, 'activation': 'selu', 'alpha_reg': 0.0001, 'batch_size': 32, 'J': 64, 'epochs': 200, 'lr': 0.0001, 'lr_decay': False, 'decay_rate': 0.96, 'decay_step': 7000, 'val_percent': 0.2, 'time_embedding': False, 'summary': True, 'save_best_model': False, 'save_complete_model': True}

# %% [markdown]
# ### Data

# %%
#path = '../../Datasets/TELCO/'
path = "/home/gastong/Documentos/TELCO/v1/" #Rosaluna
filenames_train = ["TELCO_data_2021_11.zip", "TELCO_data_2021_12.zip"]
files_train = [path+ i for i in filenames_train]

# Load data and predictions
# Read CSV files from List
data_train = pd.concat(map(pd.read_csv, files_train))
data_train = set_index(data_train)
data_train = preprocessing(data_train, flag_scaler=False, outliers=True)
data_train.head()
# Out:
#                           TS1       TS2       TS3       TS4       TS5  \
# time
# 2021-11-01 00:00:00  0.456788  0.361119  0.427533  0.821416  0.440503
# 2021-11-01 00:05:00  0.463067  0.361322  0.427533  0.693646  0.448490
# 2021-11-01 00:10:00  0.468363  0.340467  0.604864  0.612935  0.402251
# 2021-11-01 00:15:00  0.428095  0.327508  0.604864  0.859950  0.337353
# 2021-11-01 00:20:00  0.438827  0.326091  0.479911  1.040928  0.430928
#
#                           TS6       TS7       TS8       TS9  TS10      TS11  \
# time
# 2021-11-01 00:00:00  0.433320  0.478866  0.482249  0.087843  0.35  0.052165
# 2021-11-01 00:05:00  0.442270  0.367807  0.393491  0.087843  0.35  0.052165
# 2021-11-01 00:10:00  0.393046  0.475062  0.446746  0.087843  0.35  0.052165
# 2021-11-01 00:15:00  0.388198  0.486540  0.467456  0.113067  0.45  0.034588
# 2021-11-01 00:20:00  0.441524  0.448351  0.434911  0.113067  0.45  0.034588
#
#                          TS12
# time
# 2021-11-01 00:00:00  0.053619
# 2021-11-01 00:05:00  0.053619
# 2021-11-01 00:10:00  0.053619
# 2021-11-01 00:15:00  0.032172
# 2021-11-01 00:20:00  0.032172

# %%
#path = '../../Datasets/TELCO/'
path = "/home/gastong/Documentos/TELCO/v1/" #Rosaluna
filenames = ["TELCO_data_2022_01.zip", "TELCO_data_2022_02.zip", "TELCO_data_2022_03.zip", "TELCO_data_2022_04.zip",
                  "TELCO_data_2022_05.zip", "TELCO_data_2022_06.zip", "TELCO_data_2022_07.zip", "TELCO_data_2022_08.zip", 
                  "TELCO_data_2022_09.zip"]
files = [path+ i for i in filenames]

# %%
# Load data and predictions
# Read CSV files from List
data = pd.concat(map(pd.read_csv, files))
data = set_index(data)
data = preprocessing(data, flag_scaler=False, outliers=True)
data.head()
# Out:
#                           TS1       TS2       TS3       TS4       TS5  \
# time
# 2022-01-01 00:00:00  0.648864  0.505284  0.669942  0.837027  0.623184
# 2022-01-01 00:05:00  0.649752  0.497994  0.669942  0.820139  0.580578
# 2022-01-01 00:10:00  0.593288  0.476937  0.704539  0.777010  0.643936
# 2022-01-01 00:15:00  0.544374  0.467724  0.704539  0.835551  0.570099
# 2022-01-01 00:20:00  0.611489  0.443933  0.516019  0.795907  0.523654
#
#                           TS6       TS7       TS8       TS9   TS10      TS11  \
# time
# 2022-01-01 00:00:00  0.535870  0.634853  0.668639  0.247535  0.875  0.021380
# 2022-01-01 00:05:00  0.441524  0.590735  0.582840  0.247535  0.875  0.021380
# 2022-01-01 00:10:00  0.459797  0.548041  0.520710  0.247535  0.875  0.021380
# 2022-01-01 00:15:00  0.418404  0.556218  0.523669  0.151931  0.575  0.014328
# 2022-01-01 00:20:00  0.401623  0.632546  0.588757  0.151931  0.575  0.014328
#
#                          TS12
# time
# 2022-01-01 00:00:00  0.021448
# 2022-01-01 00:05:00  0.021448
# 2022-01-01 00:10:00  0.021448
# 2022-01-01 00:15:00  0.016086
# 2022-01-01 00:20:00  0.016086

# %%
#define number of rows and columns for subplots
nrow=12
ncol=1

columns_list = data.columns

time_start = '2022-09-01'
time_end = '2022-09-13'
fig, axes = plt.subplots(nrow, ncol, figsize=(20,30), constrained_layout=True, sharex=True)

# plot counter
count=0

for r in range(nrow):
    for c in range(ncol):
        data[columns_list[count]][time_start:time_end].plot(ax=axes[r])
        axes[r].set_title(columns_list[count])
        count+=1

# %% [markdown]
# ### Tada por task

# %%
data_train_task1 = data[:'2022-02-28']
data_test_task1 = data['2022-03-01':'2022-03-31']

data_train_task2 = data['2022-04-01':'2022-05-31']
data_test_task2 = data['2022-06-01':'2022-06-30']

data_train_task3 = data['2022-07-01':'2022-08-31']
data_test_task3 = data['2022-09-01':'2022-09-12']

# %% [markdown]
# ### CD

# %%
data_train_task1['TS1'] = 2 * data_train_task1['TS1'] 
data_test_task1['TS1'] = 2 * data_test_task1['TS1'] 

data_train_task2['TS1'] = 3 * data_train_task2['TS1'] 
data_test_task2['TS1'] = 3 * data_test_task2['TS1']  

data_train_task3['TS1'] = 4 * data_train_task3['TS1']  
data_test_task3['TS1'] = 4 * data_test_task3['TS1']
# Out:
# /tmp/ipykernel_307455/3666605342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_task1['TS1'] = 2 * data_train_task1['TS1']
# /tmp/ipykernel_307455/3666605342.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test_task1['TS1'] = 2 * data_test_task1['TS1']
# /tmp/ipykernel_307455/3666605342.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_task2['TS1'] = 3 * data_train_task2['TS1']
# /tmp/ipykernel_307455/3666605342.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test_task2['TS1'] = 3 * data_test_task2['TS1']
# /tmp/ipykernel_307455/3666605342.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_train_task3['TS1'] = 4 * data_train_task3['TS1']
# /tmp/ipykernel_307455/3666605342.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test_task3['TS1'] = 4 * data_test_task3['TS1']

# %%
TS1_CD = pd.concat([data_train_task1['TS1'], data_test_task1['TS1'], data_train_task2['TS1'], data_test_task2['TS1'], 
    data_train_task3['TS1'], data_test_task3['TS1']])

# %%
plt.figure(figsize=[30, 3])
TS1_CD.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# ## Task1

# %%
# Model initialization
model_task1 = DCVAE(
    settings['T'],
    settings['M'],
    settings['cnn_units'],
    settings['dil_rate'],
    settings['kernel'],
    settings['strs'],
    settings['batch_size'],
    settings['J'],
    settings['lr'],
    settings['lr_decay'],
    settings['decay_rate'],
    settings['decay_step'],
    settings['time_embedding'],
    settings['summary'],
    ) 

model_task1.vae = keras.models.load_model(settings['model_name']+'_complete.h5',
                                        custom_objects={'sampling': Sampling},
                                        compile = True)

# Compilation
opt = optimizers.Adam(learning_rate=settings['lr'])
model_task1.vae.compile(optimizer=opt)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_samples (InputLayer)      [(None, 128, 12)]    0
# __________________________________________________________________________________________________
# dcnn_enc_0 (Conv1D)             (None, 128, 64)      1536        input_samples[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_1 (Conv1D)             (None, 128, 128)     16384       dcnn_enc_0[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_2 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_1[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_3 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_2[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_4 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_3[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_5 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_4[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_6 (Conv1D)             (None, 128, 64)      16384       dcnn_enc_5[0][0]
# __________________________________________________________________________________________________
# z_mean (Conv1D)                 (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# z_log_var (Conv1D)              (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# cropping1d_6 (Cropping1D)       (None, 1, 64)        0           z_mean[0][0]
# __________________________________________________________________________________________________
# cropping1d_7 (Cropping1D)       (None, 1, 64)        0           z_log_var[0][0]
# __________________________________________________________________________________________________
# sampling_3 (Sampling)           (None, None, 64)     0           cropping1d_6[0][0]
#                                                                  cropping1d_7[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# z_sampling_z (InputLayer)       [(None, 1, 64)]      0
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 64)           0           z_sampling_z[0][0]
# __________________________________________________________________________________________________
# repeat_vector_3 (RepeatVector)  (None, 128, 64)      0           reshape_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_0 (Conv1D)             (None, 128, 64)      8192        repeat_vector_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_1 (Conv1D)             (None, 128, 128)     16384       dcnn_dec_0[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_2 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_3 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_4 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_5 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_4[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_6 (Conv1D)             (None, 128, 64)      16384       dcnn_dec_5[0][0]
# __________________________________________________________________________________________________
# x__mean_output (Conv1D)         (None, 128, 12)      768         dcnn_dec_6[0][0]
# __________________________________________________________________________________________________
# x_log_var_output (Conv1D)       (None, 128, 12)      768         dcnn_dec_6[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_task1.fit(data_train_task1,
    settings['val_percent'],
    settings['epochs'],
    settings['model_name']+'_task1',
    settings['save_best_model'],
    settings['save_complete_model'])
# Out:
# Epoch 1/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.2327 - reconst: -1.4723 - kl: 0.2396 - val_loss: -1.2647 - val_reconst: -1.5046 - val_kl: 0.2399
# Epoch 2/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.3077 - reconst: -1.5466 - kl: 0.2389 - val_loss: -1.3249 - val_reconst: -1.5535 - val_kl: 0.2287
# Epoch 3/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.3729 - reconst: -1.6048 - kl: 0.2319 - val_loss: -1.4291 - val_reconst: -1.6518 - val_kl: 0.2227
# Epoch 4/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.4376 - reconst: -1.6565 - kl: 0.2189 - val_loss: -1.4638 - val_reconst: -1.6772 - val_kl: 0.2134
# Epoch 5/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.4905 - reconst: -1.7048 - kl: 0.2143 - val_loss: -1.5266 - val_reconst: -1.7324 - val_kl: 0.2058
# Epoch 6/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.5454 - reconst: -1.7501 - kl: 0.2048 - val_loss: -1.5416 - val_reconst: -1.7386 - val_kl: 0.1970
# Epoch 7/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.5727 - reconst: -1.7748 - kl: 0.2021 - val_loss: -1.5423 - val_reconst: -1.7432 - val_kl: 0.2009
# Epoch 8/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.5995 - reconst: -1.7978 - kl: 0.1983 - val_loss: -1.6313 - val_reconst: -1.8166 - val_kl: 0.1853
# Epoch 9/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.6410 - reconst: -1.8330 - kl: 0.1920 - val_loss: -1.6511 - val_reconst: -1.8320 - val_kl: 0.1809
# Epoch 10/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.6707 - reconst: -1.8570 - kl: 0.1863 - val_loss: -1.6735 - val_reconst: -1.8804 - val_kl: 0.2068
# Epoch 11/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.6924 - reconst: -1.8766 - kl: 0.1842 - val_loss: -1.6962 - val_reconst: -1.8899 - val_kl: 0.1937
# Epoch 12/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.7115 - reconst: -1.8915 - kl: 0.1799 - val_loss: -1.7278 - val_reconst: -1.9124 - val_kl: 0.1845
# Epoch 13/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.7360 - reconst: -1.9127 - kl: 0.1767 - val_loss: -1.6978 - val_reconst: -1.8841 - val_kl: 0.1863
# Epoch 14/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.7528 - reconst: -1.9274 - kl: 0.1746 - val_loss: -1.7653 - val_reconst: -1.9378 - val_kl: 0.1725
# Epoch 15/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.7696 - reconst: -1.9442 - kl: 0.1746 - val_loss: -1.7240 - val_reconst: -1.9157 - val_kl: 0.1917
# Epoch 16/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.7835 - reconst: -1.9557 - kl: 0.1721 - val_loss: -1.7884 - val_reconst: -1.9661 - val_kl: 0.1777
# Epoch 17/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.7940 - reconst: -1.9624 - kl: 0.1683 - val_loss: -1.7844 - val_reconst: -1.9502 - val_kl: 0.1658
# Epoch 18/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8038 - reconst: -1.9785 - kl: 0.1747 - val_loss: -1.8146 - val_reconst: -1.9823 - val_kl: 0.1677
# Epoch 19/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8231 - reconst: -1.9919 - kl: 0.1688 - val_loss: -1.8256 - val_reconst: -1.9947 - val_kl: 0.1691
# Epoch 20/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8313 - reconst: -1.9983 - kl: 0.1670 - val_loss: -1.8234 - val_reconst: -1.9868 - val_kl: 0.1633
# Epoch 21/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8239 - reconst: -1.9931 - kl: 0.1692 - val_loss: -1.8150 - val_reconst: -1.9732 - val_kl: 0.1582
# Epoch 22/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8449 - reconst: -2.0133 - kl: 0.1684 - val_loss: -1.8484 - val_reconst: -2.0152 - val_kl: 0.1668
# Epoch 23/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8600 - reconst: -2.0277 - kl: 0.1677 - val_loss: -1.8689 - val_reconst: -2.0377 - val_kl: 0.1688
# Epoch 24/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8632 - reconst: -2.0307 - kl: 0.1675 - val_loss: -1.8361 - val_reconst: -2.0017 - val_kl: 0.1655
# Epoch 25/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8714 - reconst: -2.0415 - kl: 0.1701 - val_loss: -1.8515 - val_reconst: -2.0204 - val_kl: 0.1689
# Epoch 26/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8684 - reconst: -2.0378 - kl: 0.1695 - val_loss: -1.8422 - val_reconst: -2.0162 - val_kl: 0.1740
# Epoch 27/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8853 - reconst: -2.0551 - kl: 0.1698 - val_loss: -1.7909 - val_reconst: -1.9574 - val_kl: 0.1665
# Epoch 28/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8824 - reconst: -2.0531 - kl: 0.1707 - val_loss: -1.8955 - val_reconst: -2.0627 - val_kl: 0.1672
# Epoch 29/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8977 - reconst: -2.0663 - kl: 0.1686 - val_loss: -1.9106 - val_reconst: -2.0775 - val_kl: 0.1668
# Epoch 30/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.8984 - reconst: -2.0686 - kl: 0.1701 - val_loss: -1.8745 - val_reconst: -2.0422 - val_kl: 0.1677
# Epoch 31/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9041 - reconst: -2.0726 - kl: 0.1685 - val_loss: -1.8467 - val_reconst: -2.0184 - val_kl: 0.1718
# Epoch 32/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9097 - reconst: -2.0794 - kl: 0.1697 - val_loss: -1.9115 - val_reconst: -2.0807 - val_kl: 0.1691
# Epoch 33/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9146 - reconst: -2.0835 - kl: 0.1689 - val_loss: -1.9063 - val_reconst: -2.0795 - val_kl: 0.1732
# Epoch 34/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9123 - reconst: -2.0824 - kl: 0.1701 - val_loss: -1.9370 - val_reconst: -2.1043 - val_kl: 0.1673
# Epoch 35/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9225 - reconst: -2.0924 - kl: 0.1698 - val_loss: -1.9353 - val_reconst: -2.1043 - val_kl: 0.1690
# Epoch 36/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9274 - reconst: -2.0971 - kl: 0.1697 - val_loss: -1.8725 - val_reconst: -2.0434 - val_kl: 0.1709
# Epoch 37/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9335 - reconst: -2.1034 - kl: 0.1699 - val_loss: -1.9423 - val_reconst: -2.1101 - val_kl: 0.1678
# Epoch 38/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9331 - reconst: -2.1025 - kl: 0.1694 - val_loss: -1.9343 - val_reconst: -2.0982 - val_kl: 0.1639
# Epoch 39/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9389 - reconst: -2.1077 - kl: 0.1688 - val_loss: -1.9281 - val_reconst: -2.0965 - val_kl: 0.1684
# Epoch 40/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9375 - reconst: -2.1072 - kl: 0.1698 - val_loss: -1.9448 - val_reconst: -2.1118 - val_kl: 0.1671
# Epoch 41/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9511 - reconst: -2.1202 - kl: 0.1691 - val_loss: -1.9229 - val_reconst: -2.0928 - val_kl: 0.1699
# Epoch 42/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9489 - reconst: -2.1175 - kl: 0.1686 - val_loss: -1.9131 - val_reconst: -2.0807 - val_kl: 0.1675
# Epoch 43/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9476 - reconst: -2.1166 - kl: 0.1690 - val_loss: -1.9334 - val_reconst: -2.1014 - val_kl: 0.1680
# Epoch 44/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9537 - reconst: -2.1226 - kl: 0.1689 - val_loss: -1.9486 - val_reconst: -2.1192 - val_kl: 0.1706
# Epoch 45/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9645 - reconst: -2.1346 - kl: 0.1700 - val_loss: -1.9540 - val_reconst: -2.1214 - val_kl: 0.1674
# Epoch 46/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9453 - reconst: -2.1170 - kl: 0.1717 - val_loss: -1.8675 - val_reconst: -2.0494 - val_kl: 0.1819
# Epoch 47/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9544 - reconst: -2.1264 - kl: 0.1719 - val_loss: -1.9842 - val_reconst: -2.1516 - val_kl: 0.1674
# Epoch 48/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9695 - reconst: -2.1395 - kl: 0.1701 - val_loss: -1.9597 - val_reconst: -2.1278 - val_kl: 0.1681
# Epoch 49/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9702 - reconst: -2.1392 - kl: 0.1690 - val_loss: -1.9348 - val_reconst: -2.1032 - val_kl: 0.1685
# Epoch 50/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9769 - reconst: -2.1458 - kl: 0.1689 - val_loss: -1.9499 - val_reconst: -2.1172 - val_kl: 0.1672
# Epoch 51/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9716 - reconst: -2.1421 - kl: 0.1705 - val_loss: -1.9237 - val_reconst: -2.0968 - val_kl: 0.1731
# Epoch 52/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9757 - reconst: -2.1451 - kl: 0.1694 - val_loss: -1.9654 - val_reconst: -2.1351 - val_kl: 0.1697
# Epoch 53/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9778 - reconst: -2.1465 - kl: 0.1687 - val_loss: -1.9866 - val_reconst: -2.1567 - val_kl: 0.1701
# Epoch 54/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9834 - reconst: -2.1529 - kl: 0.1695 - val_loss: -1.9930 - val_reconst: -2.1607 - val_kl: 0.1677
# Epoch 55/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9916 - reconst: -2.1606 - kl: 0.1690 - val_loss: -1.9674 - val_reconst: -2.1340 - val_kl: 0.1666
# Epoch 56/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9872 - reconst: -2.1570 - kl: 0.1698 - val_loss: -1.8588 - val_reconst: -2.0307 - val_kl: 0.1719
# Epoch 57/200
# 422/422 [==============================] - 6s 14ms/step - loss: -1.9895 - reconst: -2.1590 - kl: 0.1695 - val_loss: -1.9887 - val_reconst: -2.1640 - val_kl: 0.1753
# Epoch 00057: early stopping
# WARNING:tensorflow:Found duplicated `Variable`s in Model's `weights`. This is usually caused by `Variable`s being shared by Layers in the Model. These `Variable`s will be treated as separate `Variable`s when the Model is restored. To avoid this, please save with `save_format="tf"`.

# %% [markdown]
# ### Data 0 Task 1

# %%
_, _, reconst_data0_task1, sig_data0_task1, _ = model_task1.predict(data_train,
                                        True,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task1'
                                                    )
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
likelihood_data0_task1 = likelihood_norm(data_train[settings['T']-1:], reconst_data0_task1, sig_data0_task1)
likelihood_data0_task1.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data0_task1_rest = pd.concat([likelihood_data0_task1[col] for col in likelihood_data0_task1.columns[1:]], axis=0, ignore_index=True)
likelihood_data0_task1_rest = pd.DataFrame(likelihood_data0_task1_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data0_task1_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
likelihood_data0_task1.boxplot(column=['TS1'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data 1 Task 1

# %%
_, _, reconst_data1_task1, sig_data1_task1, _ = model_task1.predict(data_test_task1,
                                        True,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task1'
                                                    )
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
likelihood_data1_task1 = likelihood_norm(data_test_task1[settings['T']-1:], reconst_data1_task1, sig_data1_task1)
likelihood_data1_task1.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data1_task1_rest = pd.concat([likelihood_data1_task1[col] for col in likelihood_data1_task1.columns[1:]], axis=0, ignore_index=True)
likelihood_data1_task1_rest = pd.DataFrame(likelihood_data1_task1_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data1_task1_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
plt.boxplot([likelihood_data0_task1_rest.values[:,0], likelihood_data1_task1_rest.values[:,0]])
plt.ylim([0.85, 1.02])
plt.title('')
plt.xticks([1, 2], ['data0_task1', 'data1_task1'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9380eb38b0>,
#   <matplotlib.axis.XTick at 0x7f9380eb3880>],
#  [Text(1, 0, 'data0_task1'), Text(2, 0, 'data1_task1')])

# %% [markdown]
# ## Task 2

# %%
# Model initialization
model_task2 = DCVAE(
    settings['T'],
    settings['M'],
    settings['cnn_units'],
    settings['dil_rate'],
    settings['kernel'],
    settings['strs'],
    settings['batch_size'],
    settings['J'],
    settings['lr'],
    settings['lr_decay'],
    settings['decay_rate'],
    settings['decay_step'],
    settings['time_embedding'],
    settings['summary'],
    ) 

model_task2.vae = keras.models.load_model(settings['model_name']+'_task1'+'_complete.h5',
                                        custom_objects={'sampling': Sampling},
                                        compile = True)

# Compilation
opt = optimizers.Adam(learning_rate=settings['lr'])
model_task2.vae.compile(optimizer=opt)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_samples (InputLayer)      [(None, 128, 12)]    0
# __________________________________________________________________________________________________
# dcnn_enc_0 (Conv1D)             (None, 128, 64)      1536        input_samples[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_1 (Conv1D)             (None, 128, 128)     16384       dcnn_enc_0[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_2 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_1[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_3 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_2[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_4 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_3[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_5 (Conv1D)             (None, 128, 128)     32768       dcnn_enc_4[0][0]
# __________________________________________________________________________________________________
# dcnn_enc_6 (Conv1D)             (None, 128, 64)      16384       dcnn_enc_5[0][0]
# __________________________________________________________________________________________________
# z_mean (Conv1D)                 (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# z_log_var (Conv1D)              (None, 128, 64)      4096        dcnn_enc_6[0][0]
# __________________________________________________________________________________________________
# cropping1d_12 (Cropping1D)      (None, 1, 64)        0           z_mean[0][0]
# __________________________________________________________________________________________________
# cropping1d_13 (Cropping1D)      (None, 1, 64)        0           z_log_var[0][0]
# __________________________________________________________________________________________________
# sampling_12 (Sampling)          (None, None, 64)     0           cropping1d_12[0][0]
#                                                                  cropping1d_13[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# z_sampling_z (InputLayer)       [(None, 1, 64)]      0
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 64)           0           z_sampling_z[0][0]
# __________________________________________________________________________________________________
# repeat_vector_6 (RepeatVector)  (None, 128, 64)      0           reshape_6[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_0 (Conv1D)             (None, 128, 64)      8192        repeat_vector_6[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_1 (Conv1D)             (None, 128, 128)     16384       dcnn_dec_0[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_2 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_1[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_3 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_2[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_4 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_3[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_5 (Conv1D)             (None, 128, 128)     32768       dcnn_dec_4[0][0]
# __________________________________________________________________________________________________
# dcnn_dec_6 (Conv1D)             (None, 128, 64)      16384       dcnn_dec_5[0][0]
# __________________________________________________________________________________________________
# x__mean_output (Conv1D)         (None, 128, 12)      768         dcnn_dec_6[0][0]
# __________________________________________________________________________________________________
# x_log_var_output (Conv1D)       (None, 128, 12)      768         dcnn_dec_6[0][0]
# ==================================================================================================
# Total params: 173,568
# Trainable params: 173,568
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
model_task2.fit(data_train_task2,
    settings['val_percent'],
    settings['epochs'],
    settings['model_name']+'_task2',
    settings['save_best_model'],
    settings['save_complete_model'])

# %% [markdown]
# ### Data 0 Task 2

# %%
_, _, reconst_data0_task2, sig_data0_task2, _ = model_task2.predict(data_train,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
likelihood_data0_task2 = likelihood_norm(data_train[settings['T']-1:], reconst_data0_task2, sig_data0_task2)
likelihood_data0_task2.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data0_task2_rest = pd.concat([likelihood_data0_task2[col] for col in likelihood_data0_task2.columns[1:]], axis=0, ignore_index=True)
likelihood_data0_task2_rest = pd.DataFrame(likelihood_data0_task2_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data0_task2_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 1 Task 2

# %%
_, _, reconst_data1_task2, sig_data1_task2, _ = model_task2.predict(data_test_task1,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
likelihood_data1_task2 = likelihood_norm(data_test_task1[settings['T']-1:], reconst_data1_task2, sig_data1_task2)
likelihood_data1_task2.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data1_task2_rest = pd.concat([likelihood_data1_task2[col] for col in likelihood_data1_task2.columns[1:]], axis=0, ignore_index=True)
likelihood_data1_task2_rest = pd.DataFrame(likelihood_data1_task2_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data1_task2_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 2 Task 2

# %%
_, _, reconst_data2_task2, sig_data2_task2, _ = model_task2.predict(data_test_task2,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task2'
                                                    )

# %%
likelihood_data2_task2 = likelihood_norm(data_test_task2[settings['T']-1:], reconst_data2_task2, sig_data2_task2)
likelihood_data2_task2.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data2_task2_rest = pd.concat([likelihood_data2_task2[col] for col in likelihood_data2_task2.columns[1:]], axis=0, ignore_index=True)
likelihood_data2_task2_rest = pd.DataFrame(likelihood_data2_task2_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data2_task2_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
plt.boxplot([likelihood_data0_task2_rest.values[:,0], likelihood_data1_task2_rest.values[:,0], likelihood_data2_task2_rest.values[:,0]])
plt.ylim([0.85, 1.02])
plt.title('')
plt.xticks([1, 2, 3], ['data0_task2', 'data1_task2', 'data2_task2'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9380e2b460>,
#   <matplotlib.axis.XTick at 0x7f9380e2b430>,
#   <matplotlib.axis.XTick at 0x7f9380dcd880>],
#  [Text(1, 0, 'data0_task2'),
#   Text(2, 0, 'data1_task2'),
#   Text(3, 0, 'data2_task2')])

# %%
plt.boxplot([likelihood_data0_task2['TS1'].values, likelihood_data1_task2['TS1'].values, likelihood_data2_task2['TS1'].values])
plt.title('')
plt.xticks([1, 2, 3], ['data0_task2', 'data1_task2', 'data2_task2'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f93b320e8e0>,
#   <matplotlib.axis.XTick at 0x7f93b320e8b0>,
#   <matplotlib.axis.XTick at 0x7f93b3197970>],
#  [Text(1, 0, 'data0_task2'),
#   Text(2, 0, 'data1_task2'),
#   Text(3, 0, 'data2_task2')])

# %% [markdown]
# ## Task 3

# %%
# Model initialization
model_task3 = DCVAE(
    settings['T'],
    settings['M'],
    settings['cnn_units'],
    settings['dil_rate'],
    settings['kernel'],
    settings['strs'],
    settings['batch_size'],
    settings['J'],
    settings['lr'],
    settings['lr_decay'],
    settings['decay_rate'],
    settings['decay_step'],
    settings['time_embedding'],
    settings['summary'],
    ) 

model_task3.vae = keras.models.load_model(settings['model_name']+'_task2'+'_complete.h5',
                                        custom_objects={'sampling': Sampling},
                                        compile = True)

# Compilation
opt = optimizers.Adam(learning_rate=settings['lr'])
model_task3.vae.compile(optimizer=opt)

# %%
model_task3 = model_task2

# %%
model_task3.fit(data_train_task3,
    settings['val_percent'],
    settings['epochs'],
    settings['model_name']+'_task3',
    settings['save_best_model'],
    settings['save_complete_model'])
# Out:
# Epoch 1/200
# 444/444 [==============================] - 43s 94ms/step - loss: -2.1803 - reconst: -2.1803 - kl: 5.7320e-06 - val_loss: -2.1053 - val_reconst: -2.1053 - val_kl: 5.3005e-06
# Epoch 2/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.2214 - reconst: -2.2214 - kl: 5.1738e-06 - val_loss: -2.2008 - val_reconst: -2.2009 - val_kl: 7.7636e-06
# Epoch 3/200
# 444/444 [==============================] - 6s 14ms/step - loss: -2.2428 - reconst: -2.2428 - kl: 5.2422e-06 - val_loss: -2.2522 - val_reconst: -2.2523 - val_kl: 8.2522e-06
# Epoch 4/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2508 - reconst: -2.2508 - kl: 5.0195e-06 - val_loss: -2.1900 - val_reconst: -2.1900 - val_kl: 1.0147e-05
# Epoch 5/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2492 - reconst: -2.2492 - kl: 4.6734e-06 - val_loss: -2.1906 - val_reconst: -2.1906 - val_kl: 4.8360e-06
# Epoch 6/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2621 - reconst: -2.2621 - kl: 4.4327e-06 - val_loss: -2.2385 - val_reconst: -2.2385 - val_kl: 4.6032e-06
# Epoch 7/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2649 - reconst: -2.2649 - kl: 4.2259e-06 - val_loss: -2.2703 - val_reconst: -2.2703 - val_kl: 3.8907e-06
# Epoch 8/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2741 - reconst: -2.2742 - kl: 4.2603e-06 - val_loss: -2.2210 - val_reconst: -2.2210 - val_kl: 2.1662e-06
# Epoch 9/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2772 - reconst: -2.2772 - kl: 4.5062e-06 - val_loss: -2.2982 - val_reconst: -2.2982 - val_kl: 4.6456e-06
# Epoch 10/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2851 - reconst: -2.2851 - kl: 3.8550e-06 - val_loss: -2.2408 - val_reconst: -2.2408 - val_kl: 3.7687e-06
# Epoch 11/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.2845 - reconst: -2.2845 - kl: 4.0121e-06 - val_loss: -2.2883 - val_reconst: -2.2883 - val_kl: 3.4635e-06
# Epoch 12/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2927 - reconst: -2.2927 - kl: 3.7666e-06 - val_loss: -1.8500 - val_reconst: -1.8500 - val_kl: 3.5940e-06
# Epoch 13/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.2869 - reconst: -2.2869 - kl: 3.8387e-06 - val_loss: -2.2767 - val_reconst: -2.2767 - val_kl: 4.9311e-06
# Epoch 14/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.2973 - reconst: -2.2973 - kl: 3.7108e-06 - val_loss: -2.2783 - val_reconst: -2.2783 - val_kl: 4.7973e-06
# Epoch 15/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.2945 - reconst: -2.2945 - kl: 3.5100e-06 - val_loss: -2.3135 - val_reconst: -2.3135 - val_kl: 4.2819e-06
# Epoch 16/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3019 - reconst: -2.3019 - kl: 3.5392e-06 - val_loss: -2.3019 - val_reconst: -2.3019 - val_kl: 5.2494e-06
# Epoch 17/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3077 - reconst: -2.3077 - kl: 3.2657e-06 - val_loss: -2.2691 - val_reconst: -2.2691 - val_kl: 2.4968e-06
# Epoch 18/200
# 444/444 [==============================] - 6s 15ms/step - loss: -2.3064 - reconst: -2.3064 - kl: 3.4073e-06 - val_loss: -2.2706 - val_reconst: -2.2706 - val_kl: 2.8492e-06
# Epoch 19/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3084 - reconst: -2.3084 - kl: 3.2943e-06 - val_loss: -2.2687 - val_reconst: -2.2687 - val_kl: 4.7814e-06
# Epoch 20/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3127 - reconst: -2.3127 - kl: 3.1353e-06 - val_loss: -2.3248 - val_reconst: -2.3248 - val_kl: 2.8982e-06
# Epoch 21/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3125 - reconst: -2.3126 - kl: 3.2051e-06 - val_loss: -2.3359 - val_reconst: -2.3359 - val_kl: 3.1304e-06
# Epoch 22/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3119 - reconst: -2.3119 - kl: 2.9914e-06 - val_loss: -2.3155 - val_reconst: -2.3155 - val_kl: 3.6286e-06
# Epoch 23/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3204 - reconst: -2.3205 - kl: 3.0324e-06 - val_loss: -2.2804 - val_reconst: -2.2804 - val_kl: 4.6174e-06
# Epoch 24/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3199 - reconst: -2.3199 - kl: 2.9308e-06 - val_loss: -2.3111 - val_reconst: -2.3111 - val_kl: 2.6388e-06
# Epoch 25/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3253 - reconst: -2.3253 - kl: 2.9513e-06 - val_loss: -2.3046 - val_reconst: -2.3046 - val_kl: 4.2361e-06
# Epoch 26/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3219 - reconst: -2.3219 - kl: 2.9154e-06 - val_loss: -2.3331 - val_reconst: -2.3331 - val_kl: 2.9168e-06
# Epoch 27/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3259 - reconst: -2.3259 - kl: 2.8059e-06 - val_loss: -2.3322 - val_reconst: -2.3322 - val_kl: 2.4538e-06
# Epoch 28/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3277 - reconst: -2.3277 - kl: 2.8085e-06 - val_loss: -2.3276 - val_reconst: -2.3276 - val_kl: 3.3079e-06
# Epoch 29/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3307 - reconst: -2.3307 - kl: 2.7695e-06 - val_loss: -2.3368 - val_reconst: -2.3368 - val_kl: 2.3294e-06
# Epoch 30/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3334 - reconst: -2.3335 - kl: 2.5087e-06 - val_loss: -2.3318 - val_reconst: -2.3318 - val_kl: 2.5212e-06
# Epoch 31/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3324 - reconst: -2.3324 - kl: 2.6545e-06 - val_loss: -2.3502 - val_reconst: -2.3502 - val_kl: 3.0487e-06
# Epoch 32/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3352 - reconst: -2.3352 - kl: 2.5673e-06 - val_loss: -2.3397 - val_reconst: -2.3397 - val_kl: 1.7226e-06
# Epoch 33/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3360 - reconst: -2.3360 - kl: 2.5020e-06 - val_loss: -2.2843 - val_reconst: -2.2843 - val_kl: 1.4206e-06
# Epoch 34/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3354 - reconst: -2.3354 - kl: 2.4684e-06 - val_loss: -2.3341 - val_reconst: -2.3341 - val_kl: 1.5050e-06
# Epoch 35/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3395 - reconst: -2.3395 - kl: 2.5369e-06 - val_loss: -2.2889 - val_reconst: -2.2889 - val_kl: 3.8657e-06
# Epoch 36/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3395 - reconst: -2.3395 - kl: 2.4057e-06 - val_loss: -2.3557 - val_reconst: -2.3558 - val_kl: 2.6764e-06
# Epoch 37/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3439 - reconst: -2.3439 - kl: 2.3947e-06 - val_loss: -2.3110 - val_reconst: -2.3110 - val_kl: 4.3026e-06
# Epoch 38/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3421 - reconst: -2.3421 - kl: 2.3748e-06 - val_loss: -2.3066 - val_reconst: -2.3066 - val_kl: 1.5683e-06
# Epoch 39/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3456 - reconst: -2.3456 - kl: 2.3627e-06 - val_loss: -2.3627 - val_reconst: -2.3627 - val_kl: 1.8184e-06
# Epoch 40/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3471 - reconst: -2.3471 - kl: 2.1891e-06 - val_loss: -2.3297 - val_reconst: -2.3297 - val_kl: 1.9360e-06
# Epoch 41/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3471 - reconst: -2.3471 - kl: 2.3669e-06 - val_loss: -2.2061 - val_reconst: -2.2061 - val_kl: 2.7458e-06
# Epoch 42/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3457 - reconst: -2.3457 - kl: 2.2987e-06 - val_loss: -2.3359 - val_reconst: -2.3359 - val_kl: 3.5868e-06
# Epoch 43/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3487 - reconst: -2.3487 - kl: 2.2395e-06 - val_loss: -2.3701 - val_reconst: -2.3701 - val_kl: 2.0816e-06
# Epoch 44/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3530 - reconst: -2.3530 - kl: 2.0008e-06 - val_loss: -2.3442 - val_reconst: -2.3442 - val_kl: 2.9499e-06
# Epoch 45/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3495 - reconst: -2.3495 - kl: 2.1404e-06 - val_loss: -2.3698 - val_reconst: -2.3698 - val_kl: 3.4046e-06
# Epoch 46/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3572 - reconst: -2.3572 - kl: 2.2599e-06 - val_loss: -2.2931 - val_reconst: -2.2931 - val_kl: 3.1418e-06
# Epoch 47/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3533 - reconst: -2.3533 - kl: 2.1068e-06 - val_loss: -2.3632 - val_reconst: -2.3632 - val_kl: 4.1944e-06
# Epoch 48/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3513 - reconst: -2.3513 - kl: 2.0909e-06 - val_loss: -2.2347 - val_reconst: -2.2347 - val_kl: 2.0382e-06
# Epoch 49/200
# 444/444 [==============================] - 7s 15ms/step - loss: -2.3504 - reconst: -2.3504 - kl: 1.9190e-06 - val_loss: -2.3314 - val_reconst: -2.3314 - val_kl: 2.5884e-06
# Epoch 00049: early stopping
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb Cell 48 in 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Brosaluna-via-gate/home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb#Y206sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model_task3.fit(data_train_task3,
#       <a href='vscode-notebook-cell://ssh-remote%2Brosaluna-via-gate/home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb#Y206sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     settings['val_percent'],
#       <a href='vscode-notebook-cell://ssh-remote%2Brosaluna-via-gate/home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb#Y206sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     settings['epochs'],
#       <a href='vscode-notebook-cell://ssh-remote%2Brosaluna-via-gate/home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb#Y206sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     settings['model_name']+'_task3',
#       <a href='vscode-notebook-cell://ssh-remote%2Brosaluna-via-gate/home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb#Y206sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     settings['save_best_model'],
#       <a href='vscode-notebook-cell://ssh-remote%2Brosaluna-via-gate/home/gastong/Documentos/DC-VAE/dc-vae_eval_GR_tasks.ipynb#Y206sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     settings['save_complete_model'])
#
# File ~/Documentos/DC-VAE/dc_vae_continual.py:261, in DCVAE.fit(self, df_X, val_percent, epochs, name, save_best_model, save_complete_model, X_gen)
#     259     self.encoder.save(name + '_encoder.h5')
#     260     self.decoder.save(name + '_decoder.h5')
# --> 261     self.vae.save(name + '_complete.h5')
#     263 return self
#
# File ~/anaconda3/envs/dcvae/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:2001, in Model.save(self, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#    1959 """Saves the model to Tensorflow SavedModel or a single HDF5 file.
#    1960
#    1961 Please see `tf.keras.models.save_model` or the
#    (...)
#    1998 ```
#    1999 """
#    2000 # pylint: enable=line-too-long
# -> 2001 save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    2002                 signatures, options, save_traces)
#
# File ~/anaconda3/envs/dcvae/lib/python3.9/site-packages/tensorflow/python/keras/saving/save.py:153, in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     144   if (not model._is_graph_network and  # pylint:disable=protected-access
#     145       not isinstance(model, sequential.Sequential)):
#     146     raise NotImplementedError(
#     147         'Saving the model to HDF5 format requires the model to be a '
#     148         'Functional model or a Sequential model. It does not work for '
#    (...)
#     151         'to the Tensorflow SavedModel format (by setting save_format="tf") '
#     152         'or using `save_weights`.')
# --> 153   hdf5_format.save_model_to_hdf5(
#     154       model, filepath, overwrite, include_optimizer)
#     155 else:
#     156   saved_model_save.save(model, filepath, overwrite, include_optimizer,
#     157                         signatures, options, save_traces)
#
# File ~/anaconda3/envs/dcvae/lib/python3.9/site-packages/tensorflow/python/keras/saving/hdf5_format.py:131, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     127   # TODO(b/128683857): Add integration tests between tf.keras and external
#     128   # Keras, to avoid breaking TF.js users.
#     129   if (include_optimizer and model.optimizer and
#     130       not isinstance(model.optimizer, optimizer_v1.TFOptimizer)):
# --> 131     save_optimizer_weights_to_hdf5_group(f, model.optimizer)
#     133   f.flush()
#     134 finally:
#
# File ~/anaconda3/envs/dcvae/lib/python3.9/site-packages/tensorflow/python/keras/saving/hdf5_format.py:595, in save_optimizer_weights_to_hdf5_group(hdf5_group, optimizer)
#     593 weight_values = K.batch_get_value(symbolic_weights)
#     594 for name, val in zip(weight_names, weight_values):
# --> 595   param_dset = weights_group.create_dataset(
#     596       name, val.shape, dtype=val.dtype)
#     597   if not val.shape:
#     598     # scalar
#     599     param_dset[()] = val
#
# File ~/anaconda3/envs/dcvae/lib/python3.9/site-packages/h5py/_hl/group.py:139, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     137 dset = dataset.Dataset(dsid)
#     138 if name is not None:
# --> 139     self[name] = dset
#     140 return dset
#
# File ~/anaconda3/envs/dcvae/lib/python3.9/site-packages/h5py/_hl/group.py:373, in Group.__setitem__(self, name, obj)
#     370 name, lcpl = self._e(name, lcpl=True)
#     372 if isinstance(obj, HLObject):
# --> 373     h5o.link(obj.id, self.id, name, lcpl=lcpl, lapl=self._lapl)
#     375 elif isinstance(obj, SoftLink):
#     376     self.id.links.create_soft(name, self._e(obj.path),
#     377                   lcpl=lcpl, lapl=self._lapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:202, in h5py.h5o.link()
#
# OSError: Unable to create link (name already exists)

# %% [markdown]
# ### Data 0 Task 3

# %%
_, _, reconst_data0_task3, sig_data0_task3, _ = model_task3.predict(data_train,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data0_task3 = likelihood_norm(data_train[settings['T']-1:], reconst_data0_task3, sig_data0_task3)
likelihood_data0_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data0_task3_rest = pd.concat([likelihood_data0_task3[col] for col in likelihood_data0_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data0_task3_rest = pd.DataFrame(likelihood_data0_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data0_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 1 Task 3

# %%
_, _, reconst_data1_task3, sig_data1_task3, _ = model_task3.predict(data_test_task1,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data1_task3 = likelihood_norm(data_test_task1[settings['T']-1:], reconst_data1_task3, sig_data1_task3)
likelihood_data1_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data1_task3_rest = pd.concat([likelihood_data1_task3[col] for col in likelihood_data1_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data1_task3_rest = pd.DataFrame(likelihood_data1_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data1_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 2 Task 3

# %%
_, _, reconst_data2_task3, sig_data2_task3, _ = model_task3.predict(data_test_task2,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data2_task3 = likelihood_norm(data_test_task2[settings['T']-1:], reconst_data2_task3, sig_data2_task3)
likelihood_data2_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data2_task3_rest = pd.concat([likelihood_data2_task3[col] for col in likelihood_data2_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data2_task3_rest = pd.DataFrame(likelihood_data2_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data2_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %% [markdown]
# ### Data 3 Task 3

# %%
_, _, reconst_data3_task3, sig_data3_task3, _ = model_task3.predict(data_test_task3,
                                        False,
                                        large_result=True,
                                        load_alpha=False,
                                        alpha_set_up = list(np.ones(12)),
                                        alpha_set_down = list(np.ones(12)),
                                        name=settings["model_name"]+'_task3'
                                                    )

# %%
likelihood_data3_task3 = likelihood_norm(data_test_task3[settings['T']-1:], reconst_data3_task3, sig_data3_task3)
likelihood_data3_task3.boxplot()
# Out:
# <AxesSubplot:>

# %%
likelihood_data3_task3_rest = pd.concat([likelihood_data3_task3[col] for col in likelihood_data3_task3.columns[1:]], axis=0, ignore_index=True)
likelihood_data3_task3_rest = pd.DataFrame(likelihood_data3_task3_rest, columns=['The other series'])  # You can change 'New Column Name' to your desired column name

likelihood_data3_task3_rest.boxplot()
plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)

# %%
plt.boxplot([likelihood_data0_task3_rest.values[:,0], likelihood_data1_task3_rest.values[:,0], likelihood_data2_task3_rest.values[:,0], likelihood_data3_task3_rest.values[:,0]])
plt.ylim([0.85, 1.02])
plt.title('')
plt.xticks([1, 2, 3, 4], ['data0_task3', 'data1_task3', 'data2_task3', 'data3_task3'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f93b3890250>,
#   <matplotlib.axis.XTick at 0x7f93b3890220>,
#   <matplotlib.axis.XTick at 0x7f93b38a3280>,
#   <matplotlib.axis.XTick at 0x7f93b3862910>],
#  [Text(1, 0, 'data0_task3'),
#   Text(2, 0, 'data1_task3'),
#   Text(3, 0, 'data2_task3'),
#   Text(4, 0, 'data3_task3')])

# %%
plt.boxplot([likelihood_data0_task3['TS1'].values, likelihood_data1_task3['TS1'].values, likelihood_data2_task3['TS1'].values, likelihood_data3_task3['TS1'].values],
 notch=True,
 bootstrap=5000)
plt.title('')
plt.xticks([1, 2, 3, 4], ['data0_task3', 'data1_task3', 'data2_task3', 'data3_task3'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f93b308e2b0>,
#   <matplotlib.axis.XTick at 0x7f93b308e280>,
#   <matplotlib.axis.XTick at 0x7f93b30b6370>,
#   <matplotlib.axis.XTick at 0x7f93b3079910>],
#  [Text(1, 0, 'data0_task3'),
#   Text(2, 0, 'data1_task3'),
#   Text(3, 0, 'data2_task3'),
#   Text(4, 0, 'data3_task3')])

# %%
likelihood_data0_task3['TS1'].shape
# Out:
# (17441,)

# %%
#define number of rows and columns for subplots
nrow=3
ncol=4

fig, axes = plt.subplots(nrow, ncol, constrained_layout=True, sharey=True)

axes[0,0].boxplot(likelihood_data0_task1['TS1'].values)
axes[0,0].set_title('Data 0')
axes[0,0].set_ylabel('Task 1')
axes[0,1].boxplot(likelihood_data1_task1['TS1'].values)
axes[0,1].set_title('Data 1')
axes[0,2].axis('off')
axes[0,2].set_title('Data 2')
axes[0,3].axis('off')
axes[0,3].set_title('Data 3')


axes[1,0].boxplot(likelihood_data0_task2['TS1'].values)
axes[1,0].set_ylabel('Task 2')
axes[1,1].boxplot(likelihood_data1_task2['TS1'].values)
axes[1,2].boxplot(likelihood_data2_task2['TS1'].values)
axes[1,3].axis('off')

axes[2,0].boxplot(likelihood_data0_task3['TS1'].values)
axes[2,0].set_ylabel('Task 3')
axes[2,1].boxplot(likelihood_data1_task3['TS1'].values)
axes[2,2].boxplot(likelihood_data2_task3['TS1'].values)
axes[2,3].boxplot(likelihood_data3_task3['TS1'].values)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f97afb43130>,
#   <matplotlib.lines.Line2D at 0x7f97afb43400>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f97afb436d0>,
#   <matplotlib.lines.Line2D at 0x7f97afb439a0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f93b2486e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f97afb43c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f97afb43f40>],
#  'means': []}

# %%
#define number of rows and columns for subplots
nrow=3
ncol=4

fig, axes = plt.subplots(nrow, ncol, constrained_layout=True, sharey=True)

axes[0,0].boxplot(likelihood_data0_task1_rest.values[:,0])
axes[0,0].set_title('Data 0')
axes[0,0].set_ylabel('Task 1')
axes[0,1].boxplot(likelihood_data1_task1_rest.values[:,0])
axes[0,1].set_title('Data 1')
axes[0,2].axis('off')
axes[0,2].set_title('Data 2')
axes[0,3].axis('off')
axes[0,3].set_title('Data 3')


axes[1,0].boxplot(likelihood_data0_task2_rest.values[:,0])
axes[1,0].set_ylabel('Task 2')
axes[1,1].boxplot(likelihood_data1_task2_rest.values[:,0])
axes[1,2].boxplot(likelihood_data2_task2_rest.values[:,0])
axes[1,3].axis('off')

axes[2,0].boxplot(likelihood_data0_task3_rest.values[:,0])
axes[2,0].set_ylabel('Task 3')
axes[2,1].boxplot(likelihood_data1_task3_rest.values[:,0])
axes[2,2].boxplot(likelihood_data2_task3_rest.values[:,0])
axes[2,3].boxplot(likelihood_data3_task3_rest.values[:,0])

plt.ylim([0.80, 1.02])
# Out:
# (0.8, 1.02)
